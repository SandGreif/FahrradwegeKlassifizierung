# %% [markdown]
# # Darstellung der Ergebnisse der Klassifizierung in Karten
#
# In diesem Jupyter Notebook wurden die Klassifizierungen in Karten dargestellt.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas
from matplotlib.colors import ListedColormap
import matplotlib.lines as mlines
from haversine import haversine

# %%
featuresDf = pandas.read_csv("../daten/merkmale_datensatz_37_bis_42/merkmaleMitLabelnFuzzyVersuch2_1_4.csv")

# %%
featuresDf['Klasse'].value_counts()
# Out:
# 0    3933
# 1    3395
# 2    1720
# Name: Klasse, dtype: int64

# %%
plt.figure(figsize=(5.5,4.5))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Fuzzy Logik Versuch 2.1.4 / Datensätze 37 bis 42')
sca = plt.scatter(featuresDf['Laengengrad'], featuresDf['Breitengrad'], c=featuresDf['Klasse'], cmap=cmapD, alpha=0.1, s=4)
cbar = plt.colorbar(sca,ticks=[2, 1, 0]) 
cbar.set_label("Fahrqualität")
cbar.set_alpha(1)
cbar.draw_all()
cbar.ax.invert_yaxis()
cbar.ax.set_yticklabels(['schlecht', 'mittel', 'gut']) 
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.grid()
plt.ylim(featuresDf['Breitengrad'].min()-0.009,featuresDf['Breitengrad'].max()+0.006)
plt.xlim(featuresDf['Laengengrad'].min()-0.009,featuresDf['Laengengrad'].max()+0.015)
plt.xticks(np.arange(np.around(featuresDf['Laengengrad'].min()-0.009,decimals=2),np.around(featuresDf['Laengengrad'].max()+0.025,decimals=2),0.06))
plt.yticks(np.arange(np.around(featuresDf['Breitengrad'].min()-0.009, decimals=2),np.around(featuresDf['Breitengrad'].max()+0.02,decimals=2),0.02))
plt.tight_layout()
plt.savefig("karteFuzzyVersuch2_1_4_datensatz37_bis_42.png")

# %%
fig = plt.figure(figsize=(8,3.5))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Fuzzy Logik Versuch 2.1.4 / Datensätze 43 und 45 bis 51')
sca = plt.scatter(featuresDf['Laengengrad'], featuresDf['Breitengrad'], c=featuresDf['Klasse'], cmap=cmapD, alpha=0.1)
cbar = plt.colorbar(sca,ticks=[2, 1, 0]) 
cbar.set_label("Fahrqualität")
cbar.set_alpha(1)
cbar.draw_all()
cbar.ax.invert_yaxis()
cbar.ax.set_yticklabels(['schlecht', 'mittel', 'gut']) 
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(featuresDf['Laengengrad'].min()-0.002,featuresDf['Laengengrad'].max()+0.002)
plt.ylim(featuresDf['Breitengrad'].min()-0.002,featuresDf['Breitengrad'].max()+0.002)
plt.xticks(np.arange(np.around(featuresDf['Laengengrad'].min()-0.0025,decimals=3),np.around(featuresDf['Laengengrad'].max(),decimals=3),0.01))
plt.yticks(np.arange(np.around(featuresDf['Breitengrad'].min()-0.0025, decimals=3),np.around(featuresDf['Breitengrad'].max()+0.003,decimals=3),0.003))
plt.grid()
plt.savefig("karteFuzzyVersuch2_1_4_datensatz43_45_bis_51.png")

# %%
fig = plt.figure(figsize=(8,3.5))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Fuzzy Logik Versuch 8.2 / Datensätze 43 und 45 bis 51')
sca = plt.scatter(featuresDf['Laengengrad'], featuresDf['Breitengrad'], c=featuresDf['Klasse'], cmap=cmapD, alpha=0.1)
cbar = plt.colorbar(sca,ticks=[2, 1, 0]) 
cbar.set_label("Fahrqualität")
cbar.set_alpha(1)
cbar.draw_all()
cbar.ax.invert_yaxis()
cbar.ax.set_yticklabels(['schlecht', 'mittel', 'gut']) 
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(featuresDf['Laengengrad'].min()-0.002,featuresDf['Laengengrad'].max()+0.002)
plt.ylim(featuresDf['Breitengrad'].min()-0.002,featuresDf['Breitengrad'].max()+0.002)
plt.xticks(np.arange(featuresDf['Laengengrad'].min(),featuresDf['Laengengrad'].max(),0.01))
plt.yticks(np.arange(featuresDf['Breitengrad'].min()-0.0025,featuresDf['Breitengrad'].max()+0.003,0.0025))
plt.grid()
#plt.savefig("karteFuzzyVersuch8_datensatz43_45_bis_51.png")

# %%
featuresDf['Breitengrad'].min()
# Out:
# 53.610390000000002

# %%
featuresDf = featuresDf[featuresDf['Klasse'] != 1]
i = 0
while i < featuresDf.shape[0]:
    labelNr = featuresDf['Klasse'].iloc[i]
    if labelNr == 2:
        featuresDf.iat[i,29] = 1
    i = i + 1

# %%
fig = plt.figure(figsize=(8,3.5))
cmapD = ListedColormap(['#cddff1','#08316d'])
plt.title('Fuzzy Logik Versuch 2.1.4 mit zwei Klassen / Datensätze 43 und 45 bis 51')
sca = plt.scatter(featuresDf['Laengengrad'], featuresDf['Breitengrad'], c=featuresDf['Klasse'], cmap=cmapD, alpha=0.1)
cbar = plt.colorbar(sca,ticks=[1, 0])
cbar.set_label("Fahrqualität")
cbar.set_alpha(1)
cbar.draw_all()
cbar.ax.invert_yaxis()
cbar.ax.set_yticklabels(['schlecht','gut'])
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(featuresDf['Laengengrad'].min()-0.002,featuresDf['Laengengrad'].max()+0.002)
plt.ylim(featuresDf['Breitengrad'].min()-0.002,featuresDf['Breitengrad'].max()+0.002)
plt.xticks(np.arange(np.around(featuresDf['Laengengrad'].min()-0.0025,decimals=3),np.around(featuresDf['Laengengrad'].max(),decimals=3),0.01))
plt.yticks(np.arange(np.around(featuresDf['Breitengrad'].min()-0.0025, decimals=3),np.around(featuresDf['Breitengrad'].max()+0.003,decimals=3),0.003))
plt.grid()
plt.savefig("karteFuzzyVersuch2_1_4_2Klassen_datensatz43_45_bis_51.png")

# %%
featuresDf['Laengengrad'].min()
# Out:
# 10.161906

# %% [markdown]
# ## OpenStreetMap Route Generator
#
# Mit den folgenden Zellen ist es möglich zu einem erfassten Datensatz eine Route in OpenStreetMap (OSM) zu erstellen. Als API wurde die OSM Test API genutzt. Der Aufruf der OSM API und Bearbeitung erfolgte mit den OSM Python wrapper [osmapi](https://github.com/metaodi/osmapi).

# %%
from osmapi import OsmApi
from haversine import haversine

# %%
MyApi = OsmApi(api="https://api06.dev.openstreetmap.org", username = u"morro34@hotmail.de", passwordfile = "C:/Users/morro/Documents/osmapipw/passwort.txt")

# %%
MyApi.ChangesetCreate({u"Klassifizierung der Fahrqualität von Radwegen": u"Dies ist eine Beispiel Anwendung für die Klassifizierung von Radwegen nach deren Fahrqualität bzw, Gleichmäßigkeit. "})
# Out:
# 126863

# %%
featuresDf = pandas.read_csv("../daten/merkmale_datensatz_52/merkmaleMitLabelnFuzzyVersuch8.csv")

# %%
featuresDf = featuresDf[:8000]

# %%
haversine([featuresDf['Breitengrad'].iloc[0],featuresDf['Laengengrad'].iloc[0]], [featuresDf['Breitengrad'].iloc[2],featuresDf['Laengengrad'].iloc[2]]) * 1000
# Out:
# 3.116520516543083

# %% [markdown]
# Die folgenden zwei Zellen erstellen eine Route (Relation) für OSM.
# Dabei gibt maxMeter den maximalen Abstand zwischen zwei Knoten an (Nodes). Ein Knoten besteht aus den Koordinaten Breitengrad und Längengrad sowie Attributen.
# Zwei Knoten werden dann durch eine Linie als Weg (Way) verbunden. Diesen Weg wird dann das Tag bzw. Attribut [smoothness](https://wiki.openstreetmap.org/wiki/Key:smoothness) zugeordnet. Hierbei muss der linguistische smoothness Wert berechnet werden.
# Dies geschieht indem die häufigste klassifizierte Klasse der Daten ausgewählt wird. Die Klassen "gut", "mittel" und "schlecht" werden dabei den smoothness Werten "good","intermediate","bad" zugeordnet.

# %%
maxMeter = 20
sumMeter = 0
ways = []
i = 0
smoothnessGood = 0
smoothnessIntermediate = 0
smoothnessBad = 0
countFeatures = 0
smoothness = 'none'
colorCode = 'none'
maxLength = len(featuresDf) - 1
lastNode = MyApi.NodeCreate({u"lon":featuresDf['Laengengrad'].iloc[i], u"lat":featuresDf['Breitengrad'].iloc[i], u"tag": {}}).get('id')
if featuresDf['Klasse'].iloc[i] == 0:
        smoothnessGood = smoothnessGood + 1
        colorCode = '#FFFFFF'
elif featuresDf['Klasse'].iloc[i] == 1:
        smoothnessIntermediate = smoothnessIntermediate + 1 
        colorCode = '#00FFFF'
elif featuresDf['Klasse'].iloc[i] == 2:
        smoothnessBad = smoothnessBad + 1
        colorCode = '#0000FF'
countFeatures = + 1

# %%
while i < maxLength:
    if featuresDf['Klasse'].iloc[i+1] == 0:
        smoothnessGood = smoothnessGood + 1
    elif featuresDf['Klasse'].iloc[i+1] == 1:
        smoothnessIntermediate = smoothnessIntermediate + 1 
    elif featuresDf['Klasse'].iloc[i+1] == 2:
        smoothnessBad = smoothnessBad + 1
    countFeatures = countFeatures + 1 
    sumMeter = sumMeter + haversine([featuresDf['Laengengrad'].iloc[i],featuresDf['Breitengrad'].iloc[i]], [featuresDf['Laengengrad'].iloc[i+1],featuresDf['Breitengrad'].iloc[i+1]]) * 1000
    if sumMeter > maxMeter:
        if smoothnessGood > smoothnessIntermediate and smoothnessGood > smoothnessBad:
            smoothness = 'good'
            colorCode = '#cddff1'
        elif smoothnessIntermediate > smoothnessBad:
            smoothness = 'intermediate'
            colorCode = '#5ba3d0'
        else:
            smoothness = 'bad'
            colorCode = '#08316d'
        smoothnessGood = 0
        smoothnessIntermediate = 0
        smoothnessBad = 0
        countFeatures = 0
        sumMeter = 0
        node = MyApi.NodeCreate({u"lon":featuresDf['Laengengrad'].iloc[i+1], u"lat":featuresDf['Breitengrad'].iloc[i+1], u"tag": {}}).get('id')
        ways.append(MyApi.WayCreate(
            {   'nd': [lastNode, node],
            'tag': { u'highway':'* ',
                    u'bicycle':'yes', 
                   u'smoothness':smoothness,
                   u'color':colorCode} 
            }).get('id'))
        lastNode = node
    i = i + 1

# %%
membersList = []
for way in ways:
    membersList.append({
      "type": "way",
      "ref": way,
      "role": ""
    })

# %%
MyApi.RelationCreate({
        'member':  membersList,
    'tag': {"name": "Höltigbaum Route"}
    })
# Out:
# {'changeset': 126863,
#  'id': 4304734764,
#  'member': [{'ref': 4305089387, 'role': '', 'type': 'way'},
#   {'ref': 4305089388, 'role': '', 'type': 'way'},
#   {'ref': 4305089389, 'role': '', 'type': 'way'},
#   {'ref': 4305089390, 'role': '', 'type': 'way'},
#   {'ref': 4305089391, 'role': '', 'type': 'way'},
#   {'ref': 4305089392, 'role': '', 'type': 'way'},
#   {'ref': 4305089393, 'role': '', 'type': 'way'},
#   {'ref': 4305089394, 'role': '', 'type': 'way'},
#   {'ref': 4305089395, 'role': '', 'type': 'way'},
#   {'ref': 4305089396, 'role': '', 'type': 'way'},
#   {'ref': 4305089397, 'role': '', 'type': 'way'},
#   {'ref': 4305089398, 'role': '', 'type': 'way'},
#   {'ref': 4305089399, 'role': '', 'type': 'way'},
#   {'ref': 4305089400, 'role': '', 'type': 'way'},
#   {'ref': 4305089401, 'role': '', 'type': 'way'},
#   {'ref': 4305089402, 'role': '', 'type': 'way'},
#   {'ref': 4305089403, 'role': '', 'type': 'way'},
#   {'ref': 4305089404, 'role': '', 'type': 'way'},
#   {'ref': 4305089405, 'role': '', 'type': 'way'},
#   {'ref': 4305089406, 'role': '', 'type': 'way'},
#   {'ref': 4305089407, 'role': '', 'type': 'way'},
#   {'ref': 4305089408, 'role': '', 'type': 'way'},
#   {'ref': 4305089409, 'role': '', 'type': 'way'},
#   {'ref': 4305089410, 'role': '', 'type': 'way'},
#   {'ref': 4305089411, 'role': '', 'type': 'way'},
#   {'ref': 4305089412, 'role': '', 'type': 'way'},
#   {'ref': 4305089413, 'role': '', 'type': 'way'},
#   {'ref': 4305089414, 'role': '', 'type': 'way'},
#   {'ref': 4305089415, 'role': '', 'type': 'way'},
#   {'ref': 4305089416, 'role': '', 'type': 'way'},
#   {'ref': 4305089417, 'role': '', 'type': 'way'},
#   {'ref': 4305089418, 'role': '', 'type': 'way'},
#   {'ref': 4305089419, 'role': '', 'type': 'way'},
#   {'ref': 4305089420, 'role': '', 'type': 'way'},
#   {'ref': 4305089421, 'role': '', 'type': 'way'},
#   {'ref': 4305089422, 'role': '', 'type': 'way'},
#   {'ref': 4305089423, 'role': '', 'type': 'way'},
#   {'ref': 4305089424, 'role': '', 'type': 'way'},
#   {'ref': 4305089425, 'role': '', 'type': 'way'},
#   {'ref': 4305089426, 'role': '', 'type': 'way'},
#   {'ref': 4305089427, 'role': '', 'type': 'way'},
#   {'ref': 4305089428, 'role': '', 'type': 'way'},
#   {'ref': 4305089429, 'role': '', 'type': 'way'},
#   {'ref': 4305089430, 'role': '', 'type': 'way'},
#   {'ref': 4305089431, 'role': '', 'type': 'way'},
#   {'ref': 4305089432, 'role': '', 'type': 'way'},
#   {'ref': 4305089433, 'role': '', 'type': 'way'},
#   {'ref': 4305089434, 'role': '', 'type': 'way'},
#   {'ref': 4305089435, 'role': '', 'type': 'way'},
#   {'ref': 4305089436, 'role': '', 'type': 'way'},
#   {'ref': 4305089437, 'role': '', 'type': 'way'},
#   {'ref': 4305089438, 'role': '', 'type': 'way'},
#   {'ref': 4305089439, 'role': '', 'type': 'way'},
#   {'ref': 4305089440, 'role': '', 'type': 'way'},
#   {'ref': 4305089441, 'role': '', 'type': 'way'},
#   {'ref': 4305089442, 'role': '', 'type': 'way'},
#   {'ref': 4305089443, 'role': '', 'type': 'way'},
#   {'ref': 4305089444, 'role': '', 'type': 'way'},
#   {'ref': 4305089445, 'role': '', 'type': 'way'},
#   {'ref': 4305089446, 'role': '', 'type': 'way'},
#   {'ref': 4305089447, 'role': '', 'type': 'way'},
#   {'ref': 4305089448, 'role': '', 'type': 'way'},
#   {'ref': 4305089449, 'role': '', 'type': 'way'},
#   {'ref': 4305089450, 'role': '', 'type': 'way'},
#   {'ref': 4305089451, 'role': '', 'type': 'way'},
#   {'ref': 4305089452, 'role': '', 'type': 'way'},
#   {'ref': 4305089453, 'role': '', 'type': 'way'},
#   {'ref': 4305089454, 'role': '', 'type': 'way'},
#   {'ref': 4305089455, 'role': '', 'type': 'way'},
#   {'ref': 4305089456, 'role': '', 'type': 'way'},
#   {'ref': 4305089457, 'role': '', 'type': 'way'},
#   {'ref': 4305089458, 'role': '', 'type': 'way'},
#   {'ref': 4305089459, 'role': '', 'type': 'way'},
#   {'ref': 4305089460, 'role': '', 'type': 'way'},
#   {'ref': 4305089461, 'role': '', 'type': 'way'},
#   {'ref': 4305089462, 'role': '', 'type': 'way'},
#   {'ref': 4305089463, 'role': '', 'type': 'way'},
#   {'ref': 4305089464, 'role': '', 'type': 'way'},
#   {'ref': 4305089465, 'role': '', 'type': 'way'},
#   {'ref': 4305089466, 'role': '', 'type': 'way'},
#   {'ref': 4305089467, 'role': '', 'type': 'way'},
#   {'ref': 4305089468, 'role': '', 'type': 'way'},
#   {'ref': 4305089469, 'role': '', 'type': 'way'},
#   {'ref': 4305089470, 'role': '', 'type': 'way'},
#   {'ref': 4305089471, 'role': '', 'type': 'way'},
#   {'ref': 4305089472, 'role': '', 'type': 'way'},
#   {'ref': 4305089473, 'role': '', 'type': 'way'},
#   {'ref': 4305089474, 'role': '', 'type': 'way'},
#   {'ref': 4305089475, 'role': '', 'type': 'way'},
#   {'ref': 4305089476, 'role': '', 'type': 'way'},
#   {'ref': 4305089477, 'role': '', 'type': 'way'},
#   {'ref': 4305089478, 'role': '', 'type': 'way'},
#   {'ref': 4305089479, 'role': '', 'type': 'way'},
#   {'ref': 4305089480, 'role': '', 'type': 'way'},
#   {'ref': 4305089481, 'role': '', 'type': 'way'},
#   {'ref': 4305089482, 'role': '', 'type': 'way'},
#   {'ref': 4305089483, 'role': '', 'type': 'way'},
#   {'ref': 4305089484, 'role': '', 'type': 'way'},
#   {'ref': 4305089485, 'role': '', 'type': 'way'},
#   {'ref': 4305089486, 'role': '', 'type': 'way'},
#   {'ref': 4305089487, 'role': '', 'type': 'way'},
#   {'ref': 4305089488, 'role': '', 'type': 'way'},
#   {'ref': 4305089489, 'role': '', 'type': 'way'},
#   {'ref': 4305089490, 'role': '', 'type': 'way'},
#   {'ref': 4305089491, 'role': '', 'type': 'way'},
#   {'ref': 4305089492, 'role': '', 'type': 'way'},
#   {'ref': 4305089493, 'role': '', 'type': 'way'},
#   {'ref': 4305089494, 'role': '', 'type': 'way'},
#   {'ref': 4305089495, 'role': '', 'type': 'way'},
#   {'ref': 4305089496, 'role': '', 'type': 'way'},
#   {'ref': 4305089497, 'role': '', 'type': 'way'},
#   {'ref': 4305089498, 'role': '', 'type': 'way'},
#   {'ref': 4305089499, 'role': '', 'type': 'way'},
#   {'ref': 4305089500, 'role': '', 'type': 'way'},
#   {'ref': 4305089501, 'role': '', 'type': 'way'},
#   {'ref': 4305089502, 'role': '', 'type': 'way'},
#   {'ref': 4305089503, 'role': '', 'type': 'way'},
#   {'ref': 4305089504, 'role': '', 'type': 'way'},
#   {'ref': 4305089505, 'role': '', 'type': 'way'},
#   {'ref': 4305089506, 'role': '', 'type': 'way'},
#   {'ref': 4305089507, 'role': '', 'type': 'way'},
#   {'ref': 4305089508, 'role': '', 'type': 'way'},
#   {'ref': 4305089509, 'role': '', 'type': 'way'},
#   {'ref': 4305089510, 'role': '', 'type': 'way'},
#   {'ref': 4305089511, 'role': '', 'type': 'way'},
#   {'ref': 4305089512, 'role': '', 'type': 'way'},
#   {'ref': 4305089513, 'role': '', 'type': 'way'},
#   {'ref': 4305089514, 'role': '', 'type': 'way'},
#   {'ref': 4305089515, 'role': '', 'type': 'way'},
#   {'ref': 4305089516, 'role': '', 'type': 'way'},
#   {'ref': 4305089517, 'role': '', 'type': 'way'},
#   {'ref': 4305089518, 'role': '', 'type': 'way'},
#   {'ref': 4305089519, 'role': '', 'type': 'way'},
#   {'ref': 4305089520, 'role': '', 'type': 'way'},
#   {'ref': 4305089521, 'role': '', 'type': 'way'},
#   {'ref': 4305089522, 'role': '', 'type': 'way'},
#   {'ref': 4305089523, 'role': '', 'type': 'way'},
#   {'ref': 4305089524, 'role': '', 'type': 'way'},
#   {'ref': 4305089525, 'role': '', 'type': 'way'},
#   {'ref': 4305089526, 'role': '', 'type': 'way'},
#   {'ref': 4305089527, 'role': '', 'type': 'way'},
#   {'ref': 4305089528, 'role': '', 'type': 'way'},
#   {'ref': 4305089529, 'role': '', 'type': 'way'},
#   {'ref': 4305089530, 'role': '', 'type': 'way'},
#   {'ref': 4305089531, 'role': '', 'type': 'way'},
#   {'ref': 4305089532, 'role': '', 'type': 'way'},
#   {'ref': 4305089533, 'role': '', 'type': 'way'},
#   {'ref': 4305089534, 'role': '', 'type': 'way'},
#   {'ref': 4305089535, 'role': '', 'type': 'way'},
#   {'ref': 4305089536, 'role': '', 'type': 'way'},
#   {'ref': 4305089537, 'role': '', 'type': 'way'},
#   {'ref': 4305089538, 'role': '', 'type': 'way'},
#   {'ref': 4305089539, 'role': '', 'type': 'way'},
#   {'ref': 4305089540, 'role': '', 'type': 'way'},
#   {'ref': 4305089541, 'role': '', 'type': 'way'},
#   {'ref': 4305089542, 'role': '', 'type': 'way'},
#   {'ref': 4305089543, 'role': '', 'type': 'way'},
#   {'ref': 4305089544, 'role': '', 'type': 'way'},
#   {'ref': 4305089545, 'role': '', 'type': 'way'},
#   {'ref': 4305089546, 'role': '', 'type': 'way'},
#   {'ref': 4305089547, 'role': '', 'type': 'way'},
#   {'ref': 4305089548, 'role': '', 'type': 'way'},
#   {'ref': 4305089549, 'role': '', 'type': 'way'},
#   {'ref': 4305089550, 'role': '', 'type': 'way'},
#   {'ref': 4305089551, 'role': '', 'type': 'way'},
#   {'ref': 4305089552, 'role': '', 'type': 'way'},
#   {'ref': 4305089553, 'role': '', 'type': 'way'},
#   {'ref': 4305089554, 'role': '', 'type': 'way'},
#   {'ref': 4305089555, 'role': '', 'type': 'way'},
#   {'ref': 4305089556, 'role': '', 'type': 'way'},
#   {'ref': 4305089557, 'role': '', 'type': 'way'},
#   {'ref': 4305089558, 'role': '', 'type': 'way'},
#   {'ref': 4305089559, 'role': '', 'type': 'way'},
#   {'ref': 4305089560, 'role': '', 'type': 'way'},
#   {'ref': 4305089561, 'role': '', 'type': 'way'},
#   {'ref': 4305089562, 'role': '', 'type': 'way'},
#   {'ref': 4305089563, 'role': '', 'type': 'way'},
#   {'ref': 4305089564, 'role': '', 'type': 'way'},
#   {'ref': 4305089565, 'role': '', 'type': 'way'},
#   {'ref': 4305089566, 'role': '', 'type': 'way'},
#   {'ref': 4305089567, 'role': '', 'type': 'way'},
#   {'ref': 4305089568, 'role': '', 'type': 'way'},
#   {'ref': 4305089569, 'role': '', 'type': 'way'},
#   {'ref': 4305089570, 'role': '', 'type': 'way'},
#   {'ref': 4305089571, 'role': '', 'type': 'way'},
#   {'ref': 4305089572, 'role': '', 'type': 'way'},
#   {'ref': 4305089573, 'role': '', 'type': 'way'},
#   {'ref': 4305089574, 'role': '', 'type': 'way'},
#   {'ref': 4305089575, 'role': '', 'type': 'way'},
#   {'ref': 4305089576, 'role': '', 'type': 'way'},
#   {'ref': 4305089577, 'role': '', 'type': 'way'},
#   {'ref': 4305089578, 'role': '', 'type': 'way'},
#   {'ref': 4305089579, 'role': '', 'type': 'way'},
#   {'ref': 4305089580, 'role': '', 'type': 'way'},
#   {'ref': 4305089581, 'role': '', 'type': 'way'},
#   {'ref': 4305089582, 'role': '', 'type': 'way'},
#   {'ref': 4305089583, 'role': '', 'type': 'way'},
#   {'ref': 4305089584, 'role': '', 'type': 'way'},
#   {'ref': 4305089585, 'role': '', 'type': 'way'},
#   {'ref': 4305089586, 'role': '', 'type': 'way'},
#   {'ref': 4305089587, 'role': '', 'type': 'way'},
#   {'ref': 4305089588, 'role': '', 'type': 'way'},
#   {'ref': 4305089589, 'role': '', 'type': 'way'},
#   {'ref': 4305089590, 'role': '', 'type': 'way'},
#   {'ref': 4305089591, 'role': '', 'type': 'way'},
#   {'ref': 4305089592, 'role': '', 'type': 'way'},
#   {'ref': 4305089593, 'role': '', 'type': 'way'},
#   {'ref': 4305089594, 'role': '', 'type': 'way'},
#   {'ref': 4305089595, 'role': '', 'type': 'way'},
#   {'ref': 4305089596, 'role': '', 'type': 'way'},
#   {'ref': 4305089597, 'role': '', 'type': 'way'},
#   {'ref': 4305089598, 'role': '', 'type': 'way'},
#   {'ref': 4305089599, 'role': '', 'type': 'way'},
#   {'ref': 4305089600, 'role': '', 'type': 'way'},
#   {'ref': 4305089601, 'role': '', 'type': 'way'},
#   {'ref': 4305089602, 'role': '', 'type': 'way'},
#   {'ref': 4305089603, 'role': '', 'type': 'way'},
#   {'ref': 4305089604, 'role': '', 'type': 'way'},
#   {'ref': 4305089605, 'role': '', 'type': 'way'},
#   {'ref': 4305089606, 'role': '', 'type': 'way'},
#   {'ref': 4305089607, 'role': '', 'type': 'way'},
#   {'ref': 4305089608, 'role': '', 'type': 'way'},
#   {'ref': 4305089609, 'role': '', 'type': 'way'},
#   {'ref': 4305089610, 'role': '', 'type': 'way'},
#   {'ref': 4305089611, 'role': '', 'type': 'way'},
#   {'ref': 4305089612, 'role': '', 'type': 'way'},
#   {'ref': 4305089613, 'role': '', 'type': 'way'},
#   {'ref': 4305089614, 'role': '', 'type': 'way'},
#   {'ref': 4305089615, 'role': '', 'type': 'way'},
#   {'ref': 4305089616, 'role': '', 'type': 'way'},
#   {'ref': 4305089617, 'role': '', 'type': 'way'},
#   {'ref': 4305089618, 'role': '', 'type': 'way'},
#   {'ref': 4305089619, 'role': '', 'type': 'way'},
#   {'ref': 4305089620, 'role': '', 'type': 'way'},
#   {'ref': 4305089621, 'role': '', 'type': 'way'},
#   {'ref': 4305089622, 'role': '', 'type': 'way'},
#   {'ref': 4305089623, 'role': '', 'type': 'way'},
#   {'ref': 4305089624, 'role': '', 'type': 'way'},
#   {'ref': 4305089625, 'role': '', 'type': 'way'},
#   {'ref': 4305089626, 'role': '', 'type': 'way'},
#   {'ref': 4305089627, 'role': '', 'type': 'way'},
#   {'ref': 4305089628, 'role': '', 'type': 'way'},
#   {'ref': 4305089629, 'role': '', 'type': 'way'},
#   {'ref': 4305089630, 'role': '', 'type': 'way'},
#   {'ref': 4305089631, 'role': '', 'type': 'way'},
#   {'ref': 4305089632, 'role': '', 'type': 'way'},
#   {'ref': 4305089633, 'role': '', 'type': 'way'},
#   {'ref': 4305089634, 'role': '', 'type': 'way'},
#   {'ref': 4305089635, 'role': '', 'type': 'way'},
#   {'ref': 4305089636, 'role': '', 'type': 'way'},
#   {'ref': 4305089637, 'role': '', 'type': 'way'},
#   {'ref': 4305089638, 'role': '', 'type': 'way'},
#   {'ref': 4305089639, 'role': '', 'type': 'way'},
#   {'ref': 4305089640, 'role': '', 'type': 'way'},
#   {'ref': 4305089641, 'role': '', 'type': 'way'},
#   {'ref': 4305089642, 'role': '', 'type': 'way'},
#   {'ref': 4305089643, 'role': '', 'type': 'way'},
#   {'ref': 4305089644, 'role': '', 'type': 'way'},
#   {'ref': 4305089645, 'role': '', 'type': 'way'},
#   {'ref': 4305089646, 'role': '', 'type': 'way'},
#   {'ref': 4305089647, 'role': '', 'type': 'way'},
#   {'ref': 4305089648, 'role': '', 'type': 'way'},
#   {'ref': 4305089649, 'role': '', 'type': 'way'},
#   {'ref': 4305089650, 'role': '', 'type': 'way'},
#   {'ref': 4305089651, 'role': '', 'type': 'way'},
#   {'ref': 4305089652, 'role': '', 'type': 'way'},
#   {'ref': 4305089653, 'role': '', 'type': 'way'},
#   {'ref': 4305089654, 'role': '', 'type': 'way'},
#   {'ref': 4305089655, 'role': '', 'type': 'way'},
#   {'ref': 4305089656, 'role': '', 'type': 'way'},
#   {'ref': 4305089657, 'role': '', 'type': 'way'},
#   {'ref': 4305089658, 'role': '', 'type': 'way'},
#   {'ref': 4305089659, 'role': '', 'type': 'way'},
#   {'ref': 4305089660, 'role': '', 'type': 'way'},
#   {'ref': 4305089661, 'role': '', 'type': 'way'},
#   {'ref': 4305089662, 'role': '', 'type': 'way'},
#   {'ref': 4305089663, 'role': '', 'type': 'way'},
#   {'ref': 4305089664, 'role': '', 'type': 'way'},
#   {'ref': 4305089665, 'role': '', 'type': 'way'},
#   {'ref': 4305089666, 'role': '', 'type': 'way'},
#   {'ref': 4305089667, 'role': '', 'type': 'way'},
#   {'ref': 4305089668, 'role': '', 'type': 'way'},
#   {'ref': 4305089669, 'role': '', 'type': 'way'},
#   {'ref': 4305089670, 'role': '', 'type': 'way'},
#   {'ref': 4305089671, 'role': '', 'type': 'way'},
#   {'ref': 4305089672, 'role': '', 'type': 'way'},
#   {'ref': 4305089673, 'role': '', 'type': 'way'},
#   {'ref': 4305089674, 'role': '', 'type': 'way'},
#   {'ref': 4305089675, 'role': '', 'type': 'way'},
#   {'ref': 4305089676, 'role': '', 'type': 'way'},
#   {'ref': 4305089677, 'role': '', 'type': 'way'},
#   {'ref': 4305089678, 'role': '', 'type': 'way'},
#   {'ref': 4305089679, 'role': '', 'type': 'way'},
#   {'ref': 4305089680, 'role': '', 'type': 'way'},
#   {'ref': 4305089681, 'role': '', 'type': 'way'},
#   {'ref': 4305089682, 'role': '', 'type': 'way'},
#   {'ref': 4305089683, 'role': '', 'type': 'way'},
#   {'ref': 4305089684, 'role': '', 'type': 'way'},
#   {'ref': 4305089685, 'role': '', 'type': 'way'},
#   {'ref': 4305089686, 'role': '', 'type': 'way'},
#   {'ref': 4305089687, 'role': '', 'type': 'way'},
#   {'ref': 4305089688, 'role': '', 'type': 'way'},
#   {'ref': 4305089689, 'role': '', 'type': 'way'},
#   {'ref': 4305089690, 'role': '', 'type': 'way'},
#   {'ref': 4305089691, 'role': '', 'type': 'way'},
#   {'ref': 4305089692, 'role': '', 'type': 'way'},
#   {'ref': 4305089693, 'role': '', 'type': 'way'},
#   {'ref': 4305089694, 'role': '', 'type': 'way'},
#   {'ref': 4305089695, 'role': '', 'type': 'way'},
#   {'ref': 4305089696, 'role': '', 'type': 'way'},
#   {'ref': 4305089697, 'role': '', 'type': 'way'},
#   {'ref': 4305089698, 'role': '', 'type': 'way'},
#   {'ref': 4305089699, 'role': '', 'type': 'way'},
#   {'ref': 4305089700, 'role': '', 'type': 'way'},
#   {'ref': 4305089701, 'role': '', 'type': 'way'},
#   {'ref': 4305089702, 'role': '', 'type': 'way'},
#   {'ref': 4305089703, 'role': '', 'type': 'way'},
#   {'ref': 4305089704, 'role': '', 'type': 'way'},
#   {'ref': 4305089705, 'role': '', 'type': 'way'},
#   {'ref': 4305089706, 'role': '', 'type': 'way'},
#   {'ref': 4305089707, 'role': '', 'type': 'way'},
#   {'ref': 4305089708, 'role': '', 'type': 'way'},
#   {'ref': 4305089709, 'role': '', 'type': 'way'},
#   {'ref': 4305089710, 'role': '', 'type': 'way'},
#   {'ref': 4305089711, 'role': '', 'type': 'way'},
#   {'ref': 4305089712, 'role': '', 'type': 'way'},
#   {'ref': 4305089713, 'role': '', 'type': 'way'},
#   {'ref': 4305089714, 'role': '', 'type': 'way'},
#   {'ref': 4305089715, 'role': '', 'type': 'way'},
#   {'ref': 4305089716, 'role': '', 'type': 'way'},
#   {'ref': 4305089717, 'role': '', 'type': 'way'},
#   {'ref': 4305089718, 'role': '', 'type': 'way'},
#   {'ref': 4305089719, 'role': '', 'type': 'way'},
#   {'ref': 4305089720, 'role': '', 'type': 'way'},
#   {'ref': 4305089721, 'role': '', 'type': 'way'},
#   {'ref': 4305089722, 'role': '', 'type': 'way'},
#   {'ref': 4305089723, 'role': '', 'type': 'way'},
#   {'ref': 4305089724, 'role': '', 'type': 'way'},
#   {'ref': 4305089725, 'role': '', 'type': 'way'},
#   {'ref': 4305089726, 'role': '', 'type': 'way'},
#   {'ref': 4305089727, 'role': '', 'type': 'way'},
#   {'ref': 4305089728, 'role': '', 'type': 'way'},
#   {'ref': 4305089729, 'role': '', 'type': 'way'},
#   {'ref': 4305089730, 'role': '', 'type': 'way'},
#   {'ref': 4305089731, 'role': '', 'type': 'way'},
#   {'ref': 4305089732, 'role': '', 'type': 'way'},
#   {'ref': 4305089733, 'role': '', 'type': 'way'},
#   {'ref': 4305089734, 'role': '', 'type': 'way'},
#   {'ref': 4305089735, 'role': '', 'type': 'way'},
#   {'ref': 4305089736, 'role': '', 'type': 'way'},
#   {'ref': 4305089737, 'role': '', 'type': 'way'},
#   {'ref': 4305089738, 'role': '', 'type': 'way'},
#   {'ref': 4305089739, 'role': '', 'type': 'way'},
#   {'ref': 4305089740, 'role': '', 'type': 'way'},
#   {'ref': 4305089741, 'role': '', 'type': 'way'},
#   {'ref': 4305089742, 'role': '', 'type': 'way'},
#   {'ref': 4305089743, 'role': '', 'type': 'way'},
#   {'ref': 4305089744, 'role': '', 'type': 'way'},
#   {'ref': 4305089745, 'role': '', 'type': 'way'},
#   {'ref': 4305089746, 'role': '', 'type': 'way'},
#   {'ref': 4305089747, 'role': '', 'type': 'way'},
#   {'ref': 4305089748, 'role': '', 'type': 'way'},
#   {'ref': 4305089749, 'role': '', 'type': 'way'},
#   {'ref': 4305089750, 'role': '', 'type': 'way'},
#   {'ref': 4305089751, 'role': '', 'type': 'way'},
#   {'ref': 4305089752, 'role': '', 'type': 'way'},
#   {'ref': 4305089753, 'role': '', 'type': 'way'},
#   {'ref': 4305089754, 'role': '', 'type': 'way'},
#   {'ref': 4305089755, 'role': '', 'type': 'way'},
#   {'ref': 4305089756, 'role': '', 'type': 'way'},
#   {'ref': 4305089757, 'role': '', 'type': 'way'},
#   {'ref': 4305089758, 'role': '', 'type': 'way'},
#   {'ref': 4305089759, 'role': '', 'type': 'way'},
#   {'ref': 4305089760, 'role': '', 'type': 'way'},
#   {'ref': 4305089761, 'role': '', 'type': 'way'},
#   {'ref': 4305089762, 'role': '', 'type': 'way'},
#   {'ref': 4305089763, 'role': '', 'type': 'way'},
#   {'ref': 4305089764, 'role': '', 'type': 'way'},
#   {'ref': 4305089765, 'role': '', 'type': 'way'},
#   {'ref': 4305089766, 'role': '', 'type': 'way'},
#   {'ref': 4305089767, 'role': '', 'type': 'way'},
#   {'ref': 4305089768, 'role': '', 'type': 'way'},
#   {'ref': 4305089769, 'role': '', 'type': 'way'},
#   {'ref': 4305089770, 'role': '', 'type': 'way'},
#   {'ref': 4305089771, 'role': '', 'type': 'way'},
#   {'ref': 4305089772, 'role': '', 'type': 'way'},
#   {'ref': 4305089773, 'role': '', 'type': 'way'},
#   {'ref': 4305089774, 'role': '', 'type': 'way'},
#   {'ref': 4305089775, 'role': '', 'type': 'way'},
#   {'ref': 4305089776, 'role': '', 'type': 'way'},
#   {'ref': 4305089777, 'role': '', 'type': 'way'},
#   {'ref': 4305089778, 'role': '', 'type': 'way'},
#   {'ref': 4305089779, 'role': '', 'type': 'way'},
#   {'ref': 4305089780, 'role': '', 'type': 'way'},
#   {'ref': 4305089781, 'role': '', 'type': 'way'},
#   {'ref': 4305089782, 'role': '', 'type': 'way'},
#   {'ref': 4305089783, 'role': '', 'type': 'way'},
#   {'ref': 4305089784, 'role': '', 'type': 'way'},
#   {'ref': 4305089785, 'role': '', 'type': 'way'},
#   {'ref': 4305089786, 'role': '', 'type': 'way'},
#   {'ref': 4305089787, 'role': '', 'type': 'way'},
#   {'ref': 4305089788, 'role': '', 'type': 'way'},
#   {'ref': 4305089789, 'role': '', 'type': 'way'},
#   {'ref': 4305089790, 'role': '', 'type': 'way'},
#   {'ref': 4305089791, 'role': '', 'type': 'way'},
#   {'ref': 4305089792, 'role': '', 'type': 'way'},
#   {'ref': 4305089793, 'role': '', 'type': 'way'},
#   {'ref': 4305089794, 'role': '', 'type': 'way'},
#   {'ref': 4305089795, 'role': '', 'type': 'way'},
#   {'ref': 4305089796, 'role': '', 'type': 'way'},
#   {'ref': 4305089797, 'role': '', 'type': 'way'},
#   {'ref': 4305089798, 'role': '', 'type': 'way'},
#   {'ref': 4305089799, 'role': '', 'type': 'way'},
#   {'ref': 4305089800, 'role': '', 'type': 'way'},
#   {'ref': 4305089801, 'role': '', 'type': 'way'},
#   {'ref': 4305089802, 'role': '', 'type': 'way'},
#   {'ref': 4305089803, 'role': '', 'type': 'way'},
#   {'ref': 4305089804, 'role': '', 'type': 'way'},
#   {'ref': 4305089805, 'role': '', 'type': 'way'},
#   {'ref': 4305089806, 'role': '', 'type': 'way'},
#   {'ref': 4305089807, 'role': '', 'type': 'way'},
#   {'ref': 4305089808, 'role': '', 'type': 'way'},
#   {'ref': 4305089809, 'role': '', 'type': 'way'},
#   {'ref': 4305089810, 'role': '', 'type': 'way'},
#   {'ref': 4305089811, 'role': '', 'type': 'way'},
#   {'ref': 4305089812, 'role': '', 'type': 'way'},
#   {'ref': 4305089813, 'role': '', 'type': 'way'},
#   {'ref': 4305089814, 'role': '', 'type': 'way'},
#   {'ref': 4305089815, 'role': '', 'type': 'way'},
#   {'ref': 4305089816, 'role': '', 'type': 'way'},
#   {'ref': 4305089817, 'role': '', 'type': 'way'},
#   {'ref': 4305089818, 'role': '', 'type': 'way'},
#   {'ref': 4305089819, 'role': '', 'type': 'way'},
#   {'ref': 4305089820, 'role': '', 'type': 'way'},
#   {'ref': 4305089821, 'role': '', 'type': 'way'},
#   {'ref': 4305089822, 'role': '', 'type': 'way'},
#   {'ref': 4305089823, 'role': '', 'type': 'way'},
#   {'ref': 4305089824, 'role': '', 'type': 'way'},
#   {'ref': 4305089825, 'role': '', 'type': 'way'},
#   {'ref': 4305089826, 'role': '', 'type': 'way'},
#   {'ref': 4305089827, 'role': '', 'type': 'way'},
#   {'ref': 4305089828, 'role': '', 'type': 'way'},
#   {'ref': 4305089829, 'role': '', 'type': 'way'},
#   {'ref': 4305089830, 'role': '', 'type': 'way'},
#   {'ref': 4305089831, 'role': '', 'type': 'way'},
#   {'ref': 4305089832, 'role': '', 'type': 'way'},
#   {'ref': 4305089833, 'role': '', 'type': 'way'},
#   {'ref': 4305089834, 'role': '', 'type': 'way'},
#   {'ref': 4305089835, 'role': '', 'type': 'way'},
#   {'ref': 4305089836, 'role': '', 'type': 'way'},
#   {'ref': 4305089837, 'role': '', 'type': 'way'},
#   {'ref': 4305089838, 'role': '', 'type': 'way'},
#   {'ref': 4305089839, 'role': '', 'type': 'way'},
#   {'ref': 4305089840, 'role': '', 'type': 'way'},
#   {'ref': 4305089841, 'role': '', 'type': 'way'},
#   {'ref': 4305089842, 'role': '', 'type': 'way'},
#   {'ref': 4305089843, 'role': '', 'type': 'way'},
#   {'ref': 4305089844, 'role': '', 'type': 'way'},
#   {'ref': 4305089845, 'role': '', 'type': 'way'},
#   {'ref': 4305089846, 'role': '', 'type': 'way'},
#   {'ref': 4305089847, 'role': '', 'type': 'way'},
#   {'ref': 4305089848, 'role': '', 'type': 'way'},
#   {'ref': 4305089849, 'role': '', 'type': 'way'},
#   {'ref': 4305089850, 'role': '', 'type': 'way'},
#   {'ref': 4305089851, 'role': '', 'type': 'way'},
#   {'ref': 4305089852, 'role': '', 'type': 'way'},
#   {'ref': 4305089853, 'role': '', 'type': 'way'},
#   {'ref': 4305089854, 'role': '', 'type': 'way'},
#   {'ref': 4305089855, 'role': '', 'type': 'way'},
#   {'ref': 4305089856, 'role': '', 'type': 'way'},
#   {'ref': 4305089857, 'role': '', 'type': 'way'},
#   {'ref': 4305089858, 'role': '', 'type': 'way'},
#   {'ref': 4305089859, 'role': '', 'type': 'way'},
#   {'ref': 4305089860, 'role': '', 'type': 'way'},
#   {'ref': 4305089861, 'role': '', 'type': 'way'},
#   {'ref': 4305089862, 'role': '', 'type': 'way'},
#   {'ref': 4305089863, 'role': '', 'type': 'way'},
#   {'ref': 4305089864, 'role': '', 'type': 'way'},
#   {'ref': 4305089865, 'role': '', 'type': 'way'},
#   {'ref': 4305089866, 'role': '', 'type': 'way'},
#   {'ref': 4305089867, 'role': '', 'type': 'way'},
#   {'ref': 4305089868, 'role': '', 'type': 'way'},
#   {'ref': 4305089869, 'role': '', 'type': 'way'},
#   {'ref': 4305089870, 'role': '', 'type': 'way'},
#   {'ref': 4305089871, 'role': '', 'type': 'way'},
#   {'ref': 4305089872, 'role': '', 'type': 'way'},
#   {'ref': 4305089873, 'role': '', 'type': 'way'},
#   {'ref': 4305089874, 'role': '', 'type': 'way'},
#   {'ref': 4305089875, 'role': '', 'type': 'way'},
#   {'ref': 4305089876, 'role': '', 'type': 'way'},
#   {'ref': 4305089877, 'role': '', 'type': 'way'},
#   {'ref': 4305089878, 'role': '', 'type': 'way'},
#   {'ref': 4305089879, 'role': '', 'type': 'way'},
#   {'ref': 4305089880, 'role': '', 'type': 'way'},
#   {'ref': 4305089881, 'role': '', 'type': 'way'},
#   {'ref': 4305089882, 'role': '', 'type': 'way'},
#   {'ref': 4305089883, 'role': '', 'type': 'way'},
#   {'ref': 4305089884, 'role': '', 'type': 'way'},
#   {'ref': 4305089885, 'role': '', 'type': 'way'},
#   {'ref': 4305089886, 'role': '', 'type': 'way'},
#   {'ref': 4305089887, 'role': '', 'type': 'way'},
#   {'ref': 4305089888, 'role': '', 'type': 'way'},
#   {'ref': 4305089889, 'role': '', 'type': 'way'},
#   {'ref': 4305089890, 'role': '', 'type': 'way'},
#   {'ref': 4305089891, 'role': '', 'type': 'way'},
#   {'ref': 4305089892, 'role': '', 'type': 'way'},
#   {'ref': 4305089893, 'role': '', 'type': 'way'},
#   {'ref': 4305089894, 'role': '', 'type': 'way'},
#   {'ref': 4305089895, 'role': '', 'type': 'way'},
#   {'ref': 4305089896, 'role': '', 'type': 'way'},
#   {'ref': 4305089897, 'role': '', 'type': 'way'},
#   {'ref': 4305089898, 'role': '', 'type': 'way'},
#   {'ref': 4305089899, 'role': '', 'type': 'way'},
#   {'ref': 4305089900, 'role': '', 'type': 'way'},
#   {'ref': 4305089901, 'role': '', 'type': 'way'},
#   {'ref': 4305089902, 'role': '', 'type': 'way'},
#   {'ref': 4305089903, 'role': '', 'type': 'way'},
#   {'ref': 4305089904, 'role': '', 'type': 'way'},
#   {'ref': 4305089905, 'role': '', 'type': 'way'},
#   {'ref': 4305089906, 'role': '', 'type': 'way'},
#   {'ref': 4305089907, 'role': '', 'type': 'way'},
#   {'ref': 4305089908, 'role': '', 'type': 'way'},
#   {'ref': 4305089909, 'role': '', 'type': 'way'},
#   {'ref': 4305089910, 'role': '', 'type': 'way'},
#   {'ref': 4305089911, 'role': '', 'type': 'way'},
#   {'ref': 4305089912, 'role': '', 'type': 'way'},
#   {'ref': 4305089913, 'role': '', 'type': 'way'},
#   {'ref': 4305089914, 'role': '', 'type': 'way'},
#   {'ref': 4305089915, 'role': '', 'type': 'way'},
#   {'ref': 4305089916, 'role': '', 'type': 'way'},
#   {'ref': 4305089917, 'role': '', 'type': 'way'},
#   {'ref': 4305089918, 'role': '', 'type': 'way'},
#   {'ref': 4305089919, 'role': '', 'type': 'way'},
#   {'ref': 4305089920, 'role': '', 'type': 'way'},
#   {'ref': 4305089921, 'role': '', 'type': 'way'},
#   {'ref': 4305089922, 'role': '', 'type': 'way'},
#   {'ref': 4305089923, 'role': '', 'type': 'way'},
#   {'ref': 4305089924, 'role': '', 'type': 'way'},
#   {'ref': 4305089925, 'role': '', 'type': 'way'},
#   {'ref': 4305089926, 'role': '', 'type': 'way'},
#   {'ref': 4305089927, 'role': '', 'type': 'way'},
#   {'ref': 4305089928, 'role': '', 'type': 'way'},
#   {'ref': 4305089929, 'role': '', 'type': 'way'},
#   {'ref': 4305089930, 'role': '', 'type': 'way'},
#   {'ref': 4305089931, 'role': '', 'type': 'way'},
#   {'ref': 4305089932, 'role': '', 'type': 'way'},
#   {'ref': 4305089933, 'role': '', 'type': 'way'},
#   {'ref': 4305089934, 'role': '', 'type': 'way'},
#   {'ref': 4305089935, 'role': '', 'type': 'way'},
#   {'ref': 4305089936, 'role': '', 'type': 'way'},
#   {'ref': 4305089937, 'role': '', 'type': 'way'},
#   {'ref': 4305089938, 'role': '', 'type': 'way'},
#   {'ref': 4305089939, 'role': '', 'type': 'way'},
#   {'ref': 4305089940, 'role': '', 'type': 'way'},
#   {'ref': 4305089941, 'role': '', 'type': 'way'},
#   {'ref': 4305089942, 'role': '', 'type': 'way'},
#   {'ref': 4305089943, 'role': '', 'type': 'way'},
#   {'ref': 4305089944, 'role': '', 'type': 'way'},
#   {'ref': 4305089945, 'role': '', 'type': 'way'},
#   {'ref': 4305089946, 'role': '', 'type': 'way'},
#   {'ref': 4305089947, 'role': '', 'type': 'way'},
#   {'ref': 4305089948, 'role': '', 'type': 'way'},
#   {'ref': 4305089949, 'role': '', 'type': 'way'},
#   {'ref': 4305089950, 'role': '', 'type': 'way'},
#   {'ref': 4305089951, 'role': '', 'type': 'way'},
#   {'ref': 4305089952, 'role': '', 'type': 'way'},
#   {'ref': 4305089953, 'role': '', 'type': 'way'},
#   {'ref': 4305089954, 'role': '', 'type': 'way'},
#   {'ref': 4305089955, 'role': '', 'type': 'way'},
#   {'ref': 4305089956, 'role': '', 'type': 'way'},
#   {'ref': 4305089957, 'role': '', 'type': 'way'},
#   {'ref': 4305089958, 'role': '', 'type': 'way'},
#   {'ref': 4305089959, 'role': '', 'type': 'way'},
#   {'ref': 4305089960, 'role': '', 'type': 'way'},
#   {'ref': 4305089961, 'role': '', 'type': 'way'},
#   {'ref': 4305089962, 'role': '', 'type': 'way'},
#   {'ref': 4305089963, 'role': '', 'type': 'way'},
#   {'ref': 4305089964, 'role': '', 'type': 'way'},
#   {'ref': 4305089965, 'role': '', 'type': 'way'},
#   {'ref': 4305089966, 'role': '', 'type': 'way'},
#   {'ref': 4305089967, 'role': '', 'type': 'way'},
#   {'ref': 4305089968, 'role': '', 'type': 'way'},
#   {'ref': 4305089969, 'role': '', 'type': 'way'},
#   {'ref': 4305089970, 'role': '', 'type': 'way'},
#   {'ref': 4305089971, 'role': '', 'type': 'way'},
#   {'ref': 4305089972, 'role': '', 'type': 'way'},
#   {'ref': 4305089973, 'role': '', 'type': 'way'},
#   {'ref': 4305089974, 'role': '', 'type': 'way'},
#   {'ref': 4305089975, 'role': '', 'type': 'way'},
#   {'ref': 4305089976, 'role': '', 'type': 'way'},
#   {'ref': 4305089977, 'role': '', 'type': 'way'},
#   {'ref': 4305089978, 'role': '', 'type': 'way'},
#   {'ref': 4305089979, 'role': '', 'type': 'way'},
#   {'ref': 4305089980, 'role': '', 'type': 'way'},
#   {'ref': 4305089981, 'role': '', 'type': 'way'},
#   {'ref': 4305089982, 'role': '', 'type': 'way'},
#   {'ref': 4305089983, 'role': '', 'type': 'way'},
#   {'ref': 4305089984, 'role': '', 'type': 'way'},
#   {'ref': 4305089985, 'role': '', 'type': 'way'},
#   {'ref': 4305089986, 'role': '', 'type': 'way'},
#   {'ref': 4305089987, 'role': '', 'type': 'way'},
#   {'ref': 4305089988, 'role': '', 'type': 'way'},
#   {'ref': 4305089989, 'role': '', 'type': 'way'},
#   {'ref': 4305089990, 'role': '', 'type': 'way'},
#   {'ref': 4305089991, 'role': '', 'type': 'way'},
#   {'ref': 4305089992, 'role': '', 'type': 'way'},
#   {'ref': 4305089993, 'role': '', 'type': 'way'},
#   {'ref': 4305089994, 'role': '', 'type': 'way'},
#   {'ref': 4305089995, 'role': '', 'type': 'way'},
#   {'ref': 4305089996, 'role': '', 'type': 'way'},
#   {'ref': 4305089997, 'role': '', 'type': 'way'},
#   {'ref': 4305089998, 'role': '', 'type': 'way'},
#   {'ref': 4305089999, 'role': '', 'type': 'way'},
#   {'ref': 4305090000, 'role': '', 'type': 'way'},
#   {'ref': 4305090001, 'role': '', 'type': 'way'},
#   {'ref': 4305090002, 'role': '', 'type': 'way'},
#   {'ref': 4305090003, 'role': '', 'type': 'way'},
#   {'ref': 4305090004, 'role': '', 'type': 'way'},
#   {'ref': 4305090005, 'role': '', 'type': 'way'},
#   {'ref': 4305090006, 'role': '', 'type': 'way'},
#   {'ref': 4305090007, 'role': '', 'type': 'way'},
#   {'ref': 4305090008, 'role': '', 'type': 'way'},
#   {'ref': 4305090009, 'role': '', 'type': 'way'},
#   {'ref': 4305090010, 'role': '', 'type': 'way'},
#   {'ref': 4305090011, 'role': '', 'type': 'way'},
#   {'ref': 4305090012, 'role': '', 'type': 'way'},
#   {'ref': 4305090013, 'role': '', 'type': 'way'},
#   {'ref': 4305090014, 'role': '', 'type': 'way'},
#   {'ref': 4305090015, 'role': '', 'type': 'way'},
#   {'ref': 4305090016, 'role': '', 'type': 'way'},
#   {'ref': 4305090017, 'role': '', 'type': 'way'},
#   {'ref': 4305090018, 'role': '', 'type': 'way'},
#   {'ref': 4305090019, 'role': '', 'type': 'way'},
#   {'ref': 4305090020, 'role': '', 'type': 'way'},
#   {'ref': 4305090021, 'role': '', 'type': 'way'},
#   {'ref': 4305090022, 'role': '', 'type': 'way'},
#   {'ref': 4305090023, 'role': '', 'type': 'way'},
#   {'ref': 4305090024, 'role': '', 'type': 'way'},
#   {'ref': 4305090025, 'role': '', 'type': 'way'},
#   {'ref': 4305090026, 'role': '', 'type': 'way'},
#   {'ref': 4305090027, 'role': '', 'type': 'way'},
#   {'ref': 4305090028, 'role': '', 'type': 'way'},
#   {'ref': 4305090029, 'role': '', 'type': 'way'},
#   {'ref': 4305090030, 'role': '', 'type': 'way'},
#   {'ref': 4305090031, 'role': '', 'type': 'way'},
#   {'ref': 4305090032, 'role': '', 'type': 'way'},
#   {'ref': 4305090033, 'role': '', 'type': 'way'},
#   {'ref': 4305090034, 'role': '', 'type': 'way'},
#   {'ref': 4305090035, 'role': '', 'type': 'way'},
#   {'ref': 4305090036, 'role': '', 'type': 'way'},
#   {'ref': 4305090037, 'role': '', 'type': 'way'},
#   {'ref': 4305090038, 'role': '', 'type': 'way'},
#   {'ref': 4305090039, 'role': '', 'type': 'way'},
#   {'ref': 4305090040, 'role': '', 'type': 'way'},
#   {'ref': 4305090041, 'role': '', 'type': 'way'},
#   {'ref': 4305090042, 'role': '', 'type': 'way'},
#   {'ref': 4305090043, 'role': '', 'type': 'way'},
#   {'ref': 4305090044, 'role': '', 'type': 'way'},
#   {'ref': 4305090045, 'role': '', 'type': 'way'},
#   {'ref': 4305090046, 'role': '', 'type': 'way'},
#   {'ref': 4305090047, 'role': '', 'type': 'way'},
#   {'ref': 4305090048, 'role': '', 'type': 'way'},
#   {'ref': 4305090049, 'role': '', 'type': 'way'},
#   {'ref': 4305090050, 'role': '', 'type': 'way'},
#   {'ref': 4305090051, 'role': '', 'type': 'way'},
#   {'ref': 4305090052, 'role': '', 'type': 'way'},
#   {'ref': 4305090053, 'role': '', 'type': 'way'},
#   {'ref': 4305090054, 'role': '', 'type': 'way'},
#   {'ref': 4305090055, 'role': '', 'type': 'way'},
#   {'ref': 4305090056, 'role': '', 'type': 'way'},
#   {'ref': 4305090057, 'role': '', 'type': 'way'},
#   {'ref': 4305090058, 'role': '', 'type': 'way'},
#   {'ref': 4305090059, 'role': '', 'type': 'way'},
#   {'ref': 4305090060, 'role': '', 'type': 'way'},
#   {'ref': 4305090061, 'role': '', 'type': 'way'},
#   {'ref': 4305090062, 'role': '', 'type': 'way'},
#   {'ref': 4305090063, 'role': '', 'type': 'way'},
#   {'ref': 4305090064, 'role': '', 'type': 'way'},
#   {'ref': 4305090065, 'role': '', 'type': 'way'},
#   {'ref': 4305090066, 'role': '', 'type': 'way'},
#   {'ref': 4305090067, 'role': '', 'type': 'way'},
#   {'ref': 4305090068, 'role': '', 'type': 'way'},
#   {'ref': 4305090069, 'role': '', 'type': 'way'},
#   {'ref': 4305090070, 'role': '', 'type': 'way'},
#   {'ref': 4305090071, 'role': '', 'type': 'way'},
#   {'ref': 4305090072, 'role': '', 'type': 'way'},
#   {'ref': 4305090073, 'role': '', 'type': 'way'},
#   {'ref': 4305090074, 'role': '', 'type': 'way'},
#   {'ref': 4305090075, 'role': '', 'type': 'way'},
#   {'ref': 4305090076, 'role': '', 'type': 'way'},
#   {'ref': 4305090077, 'role': '', 'type': 'way'},
#   {'ref': 4305090078, 'role': '', 'type': 'way'},
#   {'ref': 4305090079, 'role': '', 'type': 'way'},
#   {'ref': 4305090080, 'role': '', 'type': 'way'},
#   {'ref': 4305090081, 'role': '', 'type': 'way'},
#   {'ref': 4305090082, 'role': '', 'type': 'way'},
#   {'ref': 4305090083, 'role': '', 'type': 'way'},
#   {'ref': 4305090084, 'role': '', 'type': 'way'},
#   {'ref': 4305090085, 'role': '', 'type': 'way'},
#   {'ref': 4305090086, 'role': '', 'type': 'way'},
#   {'ref': 4305090087, 'role': '', 'type': 'way'},
#   {'ref': 4305090088, 'role': '', 'type': 'way'},
#   {'ref': 4305090089, 'role': '', 'type': 'way'},
#   {'ref': 4305090090, 'role': '', 'type': 'way'},
#   {'ref': 4305090091, 'role': '', 'type': 'way'},
#   {'ref': 4305090092, 'role': '', 'type': 'way'},
#   {'ref': 4305090093, 'role': '', 'type': 'way'},
#   {'ref': 4305090094, 'role': '', 'type': 'way'},
#   {'ref': 4305090095, 'role': '', 'type': 'way'},
#   {'ref': 4305090096, 'role': '', 'type': 'way'},
#   {'ref': 4305090097, 'role': '', 'type': 'way'},
#   {'ref': 4305090098, 'role': '', 'type': 'way'},
#   {'ref': 4305090099, 'role': '', 'type': 'way'},
#   {'ref': 4305090100, 'role': '', 'type': 'way'},
#   {'ref': 4305090101, 'role': '', 'type': 'way'},
#   {'ref': 4305090102, 'role': '', 'type': 'way'},
#   {'ref': 4305090103, 'role': '', 'type': 'way'},
#   {'ref': 4305090104, 'role': '', 'type': 'way'},
#   {'ref': 4305090105, 'role': '', 'type': 'way'},
#   {'ref': 4305090106, 'role': '', 'type': 'way'},
#   {'ref': 4305090107, 'role': '', 'type': 'way'},
#   {'ref': 4305090108, 'role': '', 'type': 'way'},
#   {'ref': 4305090109, 'role': '', 'type': 'way'},
#   {'ref': 4305090110, 'role': '', 'type': 'way'},
#   {'ref': 4305090111, 'role': '', 'type': 'way'},
#   {'ref': 4305090112, 'role': '', 'type': 'way'},
#   {'ref': 4305090113, 'role': '', 'type': 'way'},
#   {'ref': 4305090114, 'role': '', 'type': 'way'},
#   {'ref': 4305090115, 'role': '', 'type': 'way'},
#   {'ref': 4305090116, 'role': '', 'type': 'way'},
#   {'ref': 4305090117, 'role': '', 'type': 'way'},
#   {'ref': 4305090118, 'role': '', 'type': 'way'},
#   {'ref': 4305090119, 'role': '', 'type': 'way'},
#   {'ref': 4305090120, 'role': '', 'type': 'way'},
#   {'ref': 4305090121, 'role': '', 'type': 'way'},
#   {'ref': 4305090122, 'role': '', 'type': 'way'},
#   {'ref': 4305090123, 'role': '', 'type': 'way'},
#   {'ref': 4305090124, 'role': '', 'type': 'way'},
#   {'ref': 4305090125, 'role': '', 'type': 'way'},
#   {'ref': 4305090126, 'role': '', 'type': 'way'},
#   {'ref': 4305090127, 'role': '', 'type': 'way'},
#   {'ref': 4305090128, 'role': '', 'type': 'way'},
#   {'ref': 4305090129, 'role': '', 'type': 'way'},
#   {'ref': 4305090130, 'role': '', 'type': 'way'},
#   {'ref': 4305090131, 'role': '', 'type': 'way'},
#   {'ref': 4305090132, 'role': '', 'type': 'way'},
#   {'ref': 4305090133, 'role': '', 'type': 'way'},
#   {'ref': 4305090134, 'role': '', 'type': 'way'},
#   {'ref': 4305090135, 'role': '', 'type': 'way'},
#   {'ref': 4305090136, 'role': '', 'type': 'way'},
#   {'ref': 4305090137, 'role': '', 'type': 'way'},
#   {'ref': 4305090138, 'role': '', 'type': 'way'},
#   {'ref': 4305090139, 'role': '', 'type': 'way'},
#   {'ref': 4305090140, 'role': '', 'type': 'way'},
#   {'ref': 4305090141, 'role': '', 'type': 'way'},
#   {'ref': 4305090142, 'role': '', 'type': 'way'},
#   {'ref': 4305090143, 'role': '', 'type': 'way'},
#   {'ref': 4305090144, 'role': '', 'type': 'way'},
#   {'ref': 4305090145, 'role': '', 'type': 'way'},
#   {'ref': 4305090146, 'role': '', 'type': 'way'},
#   {'ref': 4305090147, 'role': '', 'type': 'way'},
#   {'ref': 4305090148, 'role': '', 'type': 'way'},
#   {'ref': 4305090149, 'role': '', 'type': 'way'},
#   {'ref': 4305090150, 'role': '', 'type': 'way'},
#   {'ref': 4305090151, 'role': '', 'type': 'way'}],
#  'tag': {'name': 'Höltigbaum Route'},
#  'version': 1}

# %% [markdown]
# # Diagramm mit gleicher Klassifizierung wie in OSM

# %%
maxMeter = 20
sumMeter = 0
smoothnessGood = 0
smoothnessIntermediate = 0
smoothnessBad = 0
fig = plt.figure(figsize=(8,3.5))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Klassifizierung des Datensatz 52 mit Fuzzy Logik Versuch 2.1.4')
color = 'none'
i = 0
indexbegin = 0
maxLength = len(featuresDf) - 1
while i < maxLength:
    if featuresDf['Klasse'].iloc[i+1] == 0:
        smoothnessGood = smoothnessGood + 1
    elif featuresDf['Klasse'].iloc[i+1] == 1:
        smoothnessIntermediate = smoothnessIntermediate + 1 
    elif featuresDf['Klasse'].iloc[i+1] == 2:
        smoothnessBad = smoothnessBad + 1
    sumMeter = sumMeter + haversine([featuresDf['Laengengrad'].iloc[i],featuresDf['Breitengrad'].iloc[i]], [featuresDf['Laengengrad'].iloc[i+1],featuresDf['Breitengrad'].iloc[i+1]]) * 1000
    if sumMeter > maxMeter:
        if smoothnessGood > smoothnessIntermediate and smoothnessGood > smoothnessBad:
            colorCode = '#b4d1ed'
        elif smoothnessIntermediate > smoothnessBad:
            colorCode = '#5ba3d0'
        else:
            colorCode = '#08316d'
        plt.plot([featuresDf['Laengengrad'].iloc[indexbegin],featuresDf['Laengengrad'].iloc[i]], [featuresDf['Breitengrad'].iloc[indexbegin],featuresDf['Breitengrad'].iloc[i]], c=colorCode, linewidth=5)
        smoothnessGood = 0
        smoothnessIntermediate = 0
        smoothnessBad = 0
        countFeatures = 0
        sumMeter = 0
        indexbegin = i
    i = i + 1
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(featuresDf['Laengengrad'].min()-0.0005,featuresDf['Laengengrad'].max()+0.0005)
plt.ylim(featuresDf['Breitengrad'].min()-0.0005,featuresDf['Breitengrad'].max()+0.0005)
plt.xticks(np.arange(np.around(featuresDf['Laengengrad'].min(),decimals=3),np.around(featuresDf['Laengengrad'].max(),decimals=3),0.01))
plt.yticks(np.arange(np.around(featuresDf['Breitengrad'].min(), decimals=3),np.around(featuresDf['Breitengrad'].max()+0.0015,decimals=3),0.003))
plt.grid()
plt.tight_layout()
good_line = mlines.Line2D([], [], color='#b4d1ed', linewidth=5, label='gut')
intermediate_line = mlines.Line2D([], [], color='#5ba3d0', linewidth=5, label='mittel')
bad_line = mlines.Line2D([], [], color='#08316d', linewidth=5, label='schlecht')
plt.legend(handles=[good_line,intermediate_line,bad_line],loc=4, title="Fahrqualität")
#plt.savefig("karteFuzzyVersuch2_1_4_datensatz52.png")

# %%
segmentFeaturesDf = featuresDf[3300:4700]

# %%
# Ausschnitt
maxMeter = 20
sumMeter = 0
smoothnessGood = 0
smoothnessIntermediate = 0
smoothnessBad = 0
fig = plt.figure(figsize=(8,3.5))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Klassifizierung des Datensatz 52 mit Fuzzy Logik Versuch 2.1.4: Wegabschnitt')
color = 'none'
i = 0
indexbegin = 0
maxLength = len(segmentFeaturesDf) - 1
while i < maxLength:
    if segmentFeaturesDf['Klasse'].iloc[i+1] == 0:
        smoothnessGood = smoothnessGood + 1
    elif segmentFeaturesDf['Klasse'].iloc[i+1] == 1:
        smoothnessIntermediate = smoothnessIntermediate + 1 
    elif segmentFeaturesDf['Klasse'].iloc[i+1] == 2:
        smoothnessBad = smoothnessBad + 1
    sumMeter = sumMeter + haversine([segmentFeaturesDf['Laengengrad'].iloc[i],segmentFeaturesDf['Breitengrad'].iloc[i]], [segmentFeaturesDf['Laengengrad'].iloc[i+1],segmentFeaturesDf['Breitengrad'].iloc[i+1]]) * 1000
    if sumMeter > maxMeter:
        if smoothnessGood > smoothnessIntermediate and smoothnessGood > smoothnessBad:
            colorCode = '#b4d1ed'
        elif smoothnessIntermediate > smoothnessBad:
            colorCode = '#5ba3d0'
        else:
            colorCode = '#08316d'
        plt.plot([segmentFeaturesDf['Laengengrad'].iloc[indexbegin],segmentFeaturesDf['Laengengrad'].iloc[i]], [segmentFeaturesDf['Breitengrad'].iloc[indexbegin],segmentFeaturesDf['Breitengrad'].iloc[i]], c=colorCode, linewidth=5)
        smoothnessGood = 0
        smoothnessIntermediate = 0
        smoothnessBad = 0
        countFeatures = 0
        sumMeter = 0
        indexbegin = i
    i = i + 1
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(segmentFeaturesDf['Laengengrad'].min()-0.0005,segmentFeaturesDf['Laengengrad'].max()+0.0005)
plt.ylim(segmentFeaturesDf['Breitengrad'].min()-0.0005,segmentFeaturesDf['Breitengrad'].max()+0.0005)
#plt.xticks(np.arange(segmentFeaturesDf['Laengengrad'].min(),segmentFeaturesDf['Laengengrad'].max(),0.005))
#plt.yticks(np.arange(segmentFeaturesDf['Breitengrad'].min(),segmentFeaturesDf['Breitengrad'].max()+0.0015,0.0025))
plt.xticks(np.arange(np.around(segmentFeaturesDf['Laengengrad'].min()-0.0004,decimals=3),np.around(segmentFeaturesDf['Laengengrad'].max()+0.0004,decimals=3),0.004))
plt.yticks(np.arange(np.around(segmentFeaturesDf['Breitengrad'].min()-0.0015, decimals=3),np.around(segmentFeaturesDf['Breitengrad'].max()+0.0015,decimals=3),0.004))
plt.grid()
plt.tight_layout()
good_line = mlines.Line2D([], [], color='#b4d1ed', linewidth=5, label='gut')
intermediate_line = mlines.Line2D([], [], color='#5ba3d0', linewidth=5, label='mittel')
bad_line = mlines.Line2D([], [], color='#08316d', linewidth=5, label='schlecht')
plt.legend(handles=[good_line,intermediate_line,bad_line],loc=4, title="Fahrqualität")
plt.savefig("karteFuzzyVersuch2_1_4_datensatz52Abschnitt.png")

# %%
# Nach Fuzzy Logik Versuch 8.2
maxMeter = 20
sumMeter = 0
smoothnessGood = 0
smoothnessIntermediate = 0
smoothnessBad = 0
fig = plt.figure(figsize=(8,3.5))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Klassifizierung des Datensatz 39 mit Fuzzy Logik Versuch 8.2')
color = 'none'
i = 0
indexbegin = 0
maxLength = len(featuresDf) - 1
while i < maxLength:
    if featuresDf['Klasse'].iloc[i+1] == 0:
        smoothnessGood = smoothnessGood + 1
    elif featuresDf['Klasse'].iloc[i+1] == 1:
        smoothnessIntermediate = smoothnessIntermediate + 1 
    elif featuresDf['Klasse'].iloc[i+1] == 2:
        smoothnessBad = smoothnessBad + 1
    sumMeter = sumMeter + haversine([featuresDf['Laengengrad'].iloc[i],featuresDf['Breitengrad'].iloc[i]], [featuresDf['Laengengrad'].iloc[i+1],featuresDf['Breitengrad'].iloc[i+1]]) * 1000
    if sumMeter > maxMeter:
        if smoothnessGood > smoothnessIntermediate and smoothnessGood > smoothnessBad:
            colorCode = '#b4d1ed'
        elif smoothnessIntermediate > smoothnessBad:
            colorCode = '#5ba3d0'
        else:
            colorCode = '#08316d'
        plt.plot([featuresDf['Laengengrad'].iloc[indexbegin],featuresDf['Laengengrad'].iloc[i]], [featuresDf['Breitengrad'].iloc[indexbegin],featuresDf['Breitengrad'].iloc[i]], c=colorCode, linewidth=5)
        smoothnessGood = 0
        smoothnessIntermediate = 0
        smoothnessBad = 0
        countFeatures = 0
        sumMeter = 0
        indexbegin = i
    i = i + 1
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(featuresDf['Laengengrad'].min()-0.0005,featuresDf['Laengengrad'].max()+0.0005)
plt.ylim(featuresDf['Breitengrad'].min()-0.0005,featuresDf['Breitengrad'].max()+0.0005)
plt.xticks(np.arange(featuresDf['Laengengrad'].min(),featuresDf['Laengengrad'].max(),0.01))
plt.yticks(np.arange(featuresDf['Breitengrad'].min(),featuresDf['Breitengrad'].max()+0.0015,0.0025))
plt.grid()
plt.tight_layout()
good_line = mlines.Line2D([], [], color='#b4d1ed', linewidth=5, label='good')
intermediate_line = mlines.Line2D([], [], color='#5ba3d0', linewidth=5, label='intermediate')
bad_line = mlines.Line2D([], [], color='#08316d', linewidth=5, label='bad')
plt.legend(handles=[good_line,intermediate_line,bad_line],loc=4)
plt.savefig("karteFuzzyVersuch8_2_datensatz39.png")

# %%
# Faltungsnetz Klassifizierung
maxMeter = 20
sumMeter = 0
smoothnessGood = 0
smoothnessIntermediate = 0
smoothnessBad = 0
fig = plt.figure(figsize=(8,3.5))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Klassifizierung des Datensatz 39')
color = 'none'
i = 0
indexbegin = 0
maxLength = len(featuresDf) - 1
while i < maxLength:
    if featuresDf['vorhergesagte Klasse'].iloc[i+1] == 0:
        smoothnessGood = smoothnessGood + 1
    elif featuresDf['vorhergesagte Klasse'].iloc[i+1] == 1:
        smoothnessIntermediate = smoothnessIntermediate + 1 
    elif featuresDf['vorhergesagte Klasse'].iloc[i+1] == 2:
        smoothnessBad = smoothnessBad + 1
    sumMeter = sumMeter + haversine([featuresDf['Laengengrad'].iloc[i],featuresDf['Breitengrad'].iloc[i]], [featuresDf['Laengengrad'].iloc[i+1],featuresDf['Breitengrad'].iloc[i+1]]) * 1000
    if sumMeter > maxMeter:
        if smoothnessGood > smoothnessIntermediate and smoothnessGood > smoothnessBad:
            colorCode = '#b4d1ed'
        elif smoothnessIntermediate > smoothnessBad:
            colorCode = '#5ba3d0'
        else:
            colorCode = '#08316d'
        plt.plot([featuresDf['Laengengrad'].iloc[indexbegin],featuresDf['Laengengrad'].iloc[i]], [featuresDf['Breitengrad'].iloc[indexbegin],featuresDf['Breitengrad'].iloc[i]], c=colorCode, linewidth=5)
        smoothnessGood = 0
        smoothnessIntermediate = 0
        smoothnessBad = 0
        countFeatures = 0
        sumMeter = 0
        indexbegin = i
    i = i + 1
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(featuresDf['Laengengrad'].min()-0.0005,featuresDf['Laengengrad'].max()+0.0005)
plt.ylim(featuresDf['Breitengrad'].min()-0.0005,featuresDf['Breitengrad'].max()+0.0005)
plt.xticks(np.arange(featuresDf['Laengengrad'].min(),featuresDf['Laengengrad'].max(),0.01))
plt.yticks(np.arange(featuresDf['Breitengrad'].min(),featuresDf['Breitengrad'].max()+0.0015,0.0025))
plt.grid()
plt.tight_layout()
good_line = mlines.Line2D([], [], color='#b4d1ed', linewidth=5, label='good')
intermediate_line = mlines.Line2D([], [], color='#5ba3d0', linewidth=5, label='intermediate')
bad_line = mlines.Line2D([], [], color='#08316d', linewidth=5, label='bad')
plt.legend(handles=[good_line,intermediate_line,bad_line],loc=4)
plt.savefig("karteVorhersageTest_4_datensatz39.png")

# %%
# Nach Fuzzy Logik Versuch 8.1 / Datensatz 39
maxMeter = 20
sumMeter = 0
smoothnessGood = 0
smoothnessIntermediate = 0
smoothnessBad = 0
fig = plt.figure(figsize=(8,5))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Klassifizierung des Datensatz 39 mit Fuzzy Logik Versuch 8.1')
color = 'none'
i = 0
indexbegin = 0
maxLength = len(featuresDf) - 1
while i < maxLength:
    if featuresDf['Klasse'].iloc[i+1] == 0:
        smoothnessGood = smoothnessGood + 1
    elif featuresDf['Klasse'].iloc[i+1] == 1:
        smoothnessIntermediate = smoothnessIntermediate + 1 
    elif featuresDf['Klasse'].iloc[i+1] == 2:
        smoothnessBad = smoothnessBad + 1
    sumMeter = sumMeter + haversine([featuresDf['Laengengrad'].iloc[i],featuresDf['Breitengrad'].iloc[i]], [featuresDf['Laengengrad'].iloc[i+1],featuresDf['Breitengrad'].iloc[i+1]]) * 1000
    if sumMeter > maxMeter:
        if smoothnessGood > smoothnessIntermediate and smoothnessGood > smoothnessBad:
            colorCode = '#b4d1ed'
        elif smoothnessIntermediate > smoothnessBad:
            colorCode = '#5ba3d0'
        else:
            colorCode = '#08316d'
        plt.plot([featuresDf['Laengengrad'].iloc[indexbegin],featuresDf['Laengengrad'].iloc[i]], [featuresDf['Breitengrad'].iloc[indexbegin],featuresDf['Breitengrad'].iloc[i]], c=colorCode, linewidth=5)
        smoothnessGood = 0
        smoothnessIntermediate = 0
        smoothnessBad = 0
        countFeatures = 0
        sumMeter = 0
        indexbegin = i
    i = i + 1
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(featuresDf['Laengengrad'].min()-0.005,featuresDf['Laengengrad'].max()+0.005)
plt.ylim(featuresDf['Breitengrad'].min()-0.005,featuresDf['Breitengrad'].max()+0.005)
plt.xticks(np.arange(featuresDf['Laengengrad'].min(),featuresDf['Laengengrad'].max(),0.02))
plt.yticks(np.arange(featuresDf['Breitengrad'].min(),featuresDf['Breitengrad'].max()+0.005,0.01))
plt.grid()
plt.tight_layout()
good_line = mlines.Line2D([], [], color='#b4d1ed', linewidth=5, label='good')
intermediate_line = mlines.Line2D([], [], color='#5ba3d0', linewidth=5, label='intermediate')
bad_line = mlines.Line2D([], [], color='#08316d', linewidth=5, label='bad')
plt.legend(handles=[good_line,intermediate_line,bad_line],loc=4)
plt.savefig("karteFuzzyVersuch8_1_datensatz39.png")

# %%
# Faltungsnetz Klassifizierung / Datensatz 39
maxMeter = 20
sumMeter = 0
smoothnessGood = 0
smoothnessIntermediate = 0
smoothnessBad = 0
fig = plt.figure(figsize=(8,5))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Klassifizierung des Datensatz 39')
color = 'none'
i = 0
indexbegin = 0
maxLength = len(featuresDf) - 1
while i < maxLength:
    if featuresDf['vorhergesagte Klasse'].iloc[i+1] == 0:
        smoothnessGood = smoothnessGood + 1
    elif featuresDf['vorhergesagte Klasse'].iloc[i+1] == 1:
        smoothnessIntermediate = smoothnessIntermediate + 1 
    elif featuresDf['vorhergesagte Klasse'].iloc[i+1] == 2:
        smoothnessBad = smoothnessBad + 1
    sumMeter = sumMeter + haversine([featuresDf['Laengengrad'].iloc[i],featuresDf['Breitengrad'].iloc[i]], [featuresDf['Laengengrad'].iloc[i+1],featuresDf['Breitengrad'].iloc[i+1]]) * 1000
    if sumMeter > maxMeter:
        if smoothnessGood > smoothnessIntermediate and smoothnessGood > smoothnessBad:
            colorCode = '#b4d1ed'
        elif smoothnessIntermediate > smoothnessBad:
            colorCode = '#5ba3d0'
        else:
            colorCode = '#08316d'
        plt.plot([featuresDf['Laengengrad'].iloc[indexbegin],featuresDf['Laengengrad'].iloc[i]], [featuresDf['Breitengrad'].iloc[indexbegin],featuresDf['Breitengrad'].iloc[i]], c=colorCode, linewidth=5)
        smoothnessGood = 0
        smoothnessIntermediate = 0
        smoothnessBad = 0
        countFeatures = 0
        sumMeter = 0
        indexbegin = i
    i = i + 1
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(featuresDf['Laengengrad'].min()-0.005,featuresDf['Laengengrad'].max()+0.005)
plt.ylim(featuresDf['Breitengrad'].min()-0.005,featuresDf['Breitengrad'].max()+0.005)
plt.xticks(np.arange(featuresDf['Laengengrad'].min(),featuresDf['Laengengrad'].max(),0.02))
plt.yticks(np.arange(featuresDf['Breitengrad'].min(),featuresDf['Breitengrad'].max()+0.005,0.01))
plt.grid()
plt.tight_layout()
good_line = mlines.Line2D([], [], color='#b4d1ed', linewidth=5, label='good')
intermediate_line = mlines.Line2D([], [], color='#5ba3d0', linewidth=5, label='intermediate')
bad_line = mlines.Line2D([], [], color='#08316d', linewidth=5, label='bad')
plt.legend(handles=[good_line,intermediate_line,bad_line],loc=4)
plt.savefig("karteVorhersageTest_4_datensatz39.png")
