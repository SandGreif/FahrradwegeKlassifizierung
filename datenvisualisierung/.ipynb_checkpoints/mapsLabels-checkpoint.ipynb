# %% [markdown]
# # Darstellung der Ergebnisse der Klassifizierung in Karten
#
# In diesem Jupyter Notebook wurden die Klassifizierungen in Karten dargestellt.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas
from matplotlib.colors import ListedColormap

# %%
featuresDf = pandas.read_csv("../daten/merkmale_datensatz_43_45_bis_51/merkmaleMitLabelnFuzzyVersuch6.csv")

# %%
featuresDf['Klasse'].value_counts()
# Out:
# 1    63909
# 0    39591
# 2    12290
# Name: Klasse, dtype: int64

# %%
plt.figure(figsize=(10,10))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Fuzzy Logik Versuch 4 / Datensätze 37 bis 42')
sca = plt.scatter(featuresDf['Laengengrad'], featuresDf['Breitengrad'], c=featuresDf['Klasse'], cmap=cmapD, alpha=0.1)
cbar = plt.colorbar(sca,ticks=[2, 1, 0]) 
cbar.set_label("Fahrqualität")
cbar.set_alpha(1)
cbar.draw_all()
cbar.ax.invert_yaxis()
cbar.ax.set_yticklabels(['schlecht', 'mittel', 'gut']) 
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.grid()
plt.savefig("karteFuzzyVersuch4_datensatz37_bis_42.png")

# %%
fig = plt.figure(figsize=(8,3.5))
cmapD = ListedColormap(['#cddff1','#5ba3d0','#08316d'])
plt.title('Fuzzy Logik Versuch 6 / Datensätze 43 und 45 bis 51')
sca = plt.scatter(featuresDf['Laengengrad'], featuresDf['Breitengrad'], c=featuresDf['Klasse'], cmap=cmapD, alpha=0.1)
cbar = plt.colorbar(sca,ticks=[2, 1, 0]) 
cbar.set_label("Fahrqualität")
cbar.set_alpha(1)
cbar.draw_all()
cbar.ax.invert_yaxis()
cbar.ax.set_yticklabels(['schlecht', 'mittel', 'gut']) 
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(featuresDf['Laengengrad'].min()-0.002,featuresDf['Laengengrad'].max()+0.002)
plt.ylim(featuresDf['Breitengrad'].min()-0.002,featuresDf['Breitengrad'].max()+0.002)
plt.xticks(np.arange(featuresDf['Laengengrad'].min(),featuresDf['Laengengrad'].max(),0.01))
plt.yticks(np.arange(featuresDf['Breitengrad'].min()-0.0025,featuresDf['Breitengrad'].max()+0.003,0.0025))
plt.grid()
plt.savefig("karteFuzzyVersuch6_datensatz43_45_bis_51.png")

# %%
featuresDf['Breitengrad'].min()
# Out:
# 53.610390000000002

# %%
featuresDf = featuresDf[featuresDf['Klasse'] != 1]
i = 0
while i < featuresDf.shape[0]:
    labelNr = featuresDf['Klasse'].iloc[i]
    if labelNr == 2:
        featuresDf.iat[i,29] = 1
    i = i + 1

# %%
fig = plt.figure(figsize=(8,3.5))
cmapD = ListedColormap(['#cddff1','#08316d'])
plt.title('Fuzzy Logik Versuch 6 mit zwei Klassen / Datensätze 43 und 45 bis 51')
sca = plt.scatter(featuresDf['Laengengrad'], featuresDf['Breitengrad'], c=featuresDf['Klasse'], cmap=cmapD, alpha=0.1)
cbar = plt.colorbar(sca,ticks=[1, 0])
cbar.set_label("Fahrqualität")
cbar.set_alpha(1)
cbar.draw_all()
cbar.ax.invert_yaxis()
cbar.ax.set_yticklabels(['schlecht','gut'])
plt.xlabel('Längengrad in Dezimalgrad')
plt.ylabel('Breitengrad in Dezimalgrad')
plt.xlim(featuresDf['Laengengrad'].min()-0.002,featuresDf['Laengengrad'].max()+0.002)
plt.ylim(featuresDf['Breitengrad'].min()-0.002,featuresDf['Breitengrad'].max()+0.002)
plt.xticks(np.arange(featuresDf['Laengengrad'].min(),featuresDf['Laengengrad'].max(),0.01))
plt.yticks(np.arange(featuresDf['Breitengrad'].min()-0.0025,featuresDf['Breitengrad'].max()+0.003,0.0025))
plt.grid()
plt.savefig("karteFuzzyVersuch6_2Klassen_datensatz43_45_bis_51.png")

# %%
featuresDf['Laengengrad'].min()
# Out:
# 10.161906

# %% [markdown]
# ## OpenStreetMap Route Generator
#
# Mit den folgenden Zellen ist es möglich zu einem erfassten Datensatz eine Route in OpenStreetMap (OSM) zu erstellen. Als API wurde die OSM Test API genutzt. Der Aufruf der OSM API und Bearbeitung erfolgte mit den OSM Python wrapper [osmapi](https://github.com/metaodi/osmapi).

# %%
from osmapi import OsmApi
from haversine import haversine

# %%
MyApi = OsmApi(api="https://api06.dev.openstreetmap.org", username = u"morro34@hotmail.de", passwordfile = "C:/Users/morro/Documents/osmapipw/passwort.txt")

# %%
MyApi.ChangesetCreate({u"test": u"My first test"})
# Out:
# 126676

# %%
featuresDf = pandas.read_csv("../daten/merkmale_datensatz_43_45_bis_51/merkmaleMitLabelnFuzzyVersuch6.csv")

# %%
haversine([featuresDf['Breitengrad'].iloc[0],featuresDf['Laengengrad'].iloc[0]], [featuresDf['Breitengrad'].iloc[2],featuresDf['Laengengrad'].iloc[2]]) * 1000
# Out:
# 2.383498981571627

# %%
featuresDf = featuresDf[:8000]

# %% [markdown]
# Die folgenden zwei Zellen erstellen eine Route (Relation) für OSM.
# Dabei gibt maxMeter den maximalen Abstand zwischen zwei Knoten an (Nodes). Ein Knoten besteht aus den Koordinaten Breitengrad und Längengrad sowie Attributen.
# Zwei Knoten werden dann durch eine Linie als Weg (Way) verbunden. Diesen Weg wird dann das Tag bzw. Attribut [smoothness](https://wiki.openstreetmap.org/wiki/Key:smoothness) zugeordnet. Hierbei muss der linguistische smoothness Wert berechnet werden.
# Dies geschieht indem die häufigste klassifizierte Klasse der Daten ausgewählt wird. Die Klassen "gut", "mittel" und "schlecht" werden dabei den smoothness Werten "good","intermediate","bad" zugeordnet.

# %%
maxMeter = 100
ways = []
i = 0
smoothnessGood = 0
smoothnessIntermediate = 0
smoothnessBad = 0
countFeatures = 0
smoothness = 'unknown'
maxLength = len(featuresDf) - 1
lastNode = MyApi.NodeCreate({u"lon":featuresDf['Laengengrad'].iloc[i], u"lat":featuresDf['Breitengrad'].iloc[i], u"tag": {}}).get('id')
if featuresDf['Klasse'].iloc[i] == 0:
       smoothnessGood = smoothnessGood + 1
elif featuresDf['Klasse'].iloc[i] == 1:
       smoothnessIntermediate = smoothnessIntermediate + 1 
elif featuresDf['Klasse'].iloc[i] == 2:
       smoothnessBad = smoothnessBad + 1
countFeatures = + 1

# %%
while i < maxLength:
    if featuresDf['Klasse'].iloc[i+1] == 0:
        smoothnessGood = smoothnessGood + 1
    elif featuresDf['Klasse'].iloc[i+1] == 1:
        smoothnessIntermediate = smoothnessIntermediate + 1 
    elif featuresDf['Klasse'].iloc[i+1] == 2:
        smoothnessBad = smoothnessBad + 1
    countFeatures = countFeatures + 1 
    sumMeter = sumMeter + haversine([featuresDf['Laengengrad'].iloc[i],featuresDf['Breitengrad'].iloc[i]], [featuresDf['Laengengrad'].iloc[i+1],featuresDf['Breitengrad'].iloc[i+1]]) * 1000
    if sumMeter > maxMeter:
        if smoothnessGood > smoothnessIntermediate and smoothnessGood > smoothnessBad:
            smoothness = 'good'
        elif smoothnessIntermediate > smoothnessBad:
            smoothness = 'intermediate'
        else:
            smoothness = 'bad' 
        smoothnessGood = 0
        smoothnessIntermediate = 0
        smoothnessBad = 0
        countFeatures = 0
        sumMeter = 0
        node = MyApi.NodeCreate({u"lon":featuresDf['Laengengrad'].iloc[i+1], u"lat":featuresDf['Breitengrad'].iloc[i+1], u"tag": {}}).get('id')
        ways.append(MyApi.WayCreate(
            {   'nd': [lastNode, node],
            'tag': { u'highway':'*',
                   u'smoothness':smoothness} 
            }).get('id'))
        lastNode = node
    i = i + 1

# %%
membersList = []
for way in ways:
    membersList.append({
      "type": "way",
      "ref": way,
      "role": ""
    })

# %%
MyApi.RelationCreate({
        'member':  membersList,
    'tag': {"name": "Höltigbaum Route"}
    })
# Out:
# {'changeset': 126676,
#  'id': 4304706491,
#  'member': [{'ref': 4305060119, 'role': '', 'type': 'way'},
#   {'ref': 4305060120, 'role': '', 'type': 'way'},
#   {'ref': 4305060121, 'role': '', 'type': 'way'},
#   {'ref': 4305060122, 'role': '', 'type': 'way'},
#   {'ref': 4305060123, 'role': '', 'type': 'way'},
#   {'ref': 4305060124, 'role': '', 'type': 'way'},
#   {'ref': 4305060125, 'role': '', 'type': 'way'},
#   {'ref': 4305060126, 'role': '', 'type': 'way'},
#   {'ref': 4305060127, 'role': '', 'type': 'way'},
#   {'ref': 4305060128, 'role': '', 'type': 'way'},
#   {'ref': 4305060129, 'role': '', 'type': 'way'},
#   {'ref': 4305060130, 'role': '', 'type': 'way'},
#   {'ref': 4305060131, 'role': '', 'type': 'way'},
#   {'ref': 4305060132, 'role': '', 'type': 'way'},
#   {'ref': 4305060133, 'role': '', 'type': 'way'},
#   {'ref': 4305060134, 'role': '', 'type': 'way'},
#   {'ref': 4305060135, 'role': '', 'type': 'way'},
#   {'ref': 4305060136, 'role': '', 'type': 'way'},
#   {'ref': 4305060137, 'role': '', 'type': 'way'},
#   {'ref': 4305060138, 'role': '', 'type': 'way'},
#   {'ref': 4305060139, 'role': '', 'type': 'way'},
#   {'ref': 4305060140, 'role': '', 'type': 'way'},
#   {'ref': 4305060141, 'role': '', 'type': 'way'},
#   {'ref': 4305060142, 'role': '', 'type': 'way'},
#   {'ref': 4305060143, 'role': '', 'type': 'way'},
#   {'ref': 4305060144, 'role': '', 'type': 'way'},
#   {'ref': 4305060145, 'role': '', 'type': 'way'},
#   {'ref': 4305060146, 'role': '', 'type': 'way'},
#   {'ref': 4305060147, 'role': '', 'type': 'way'},
#   {'ref': 4305060148, 'role': '', 'type': 'way'},
#   {'ref': 4305060149, 'role': '', 'type': 'way'},
#   {'ref': 4305060150, 'role': '', 'type': 'way'},
#   {'ref': 4305060151, 'role': '', 'type': 'way'},
#   {'ref': 4305060152, 'role': '', 'type': 'way'},
#   {'ref': 4305060153, 'role': '', 'type': 'way'},
#   {'ref': 4305060154, 'role': '', 'type': 'way'},
#   {'ref': 4305060155, 'role': '', 'type': 'way'},
#   {'ref': 4305060156, 'role': '', 'type': 'way'},
#   {'ref': 4305060157, 'role': '', 'type': 'way'},
#   {'ref': 4305060158, 'role': '', 'type': 'way'},
#   {'ref': 4305060159, 'role': '', 'type': 'way'},
#   {'ref': 4305060160, 'role': '', 'type': 'way'},
#   {'ref': 4305060161, 'role': '', 'type': 'way'},
#   {'ref': 4305060162, 'role': '', 'type': 'way'},
#   {'ref': 4305060163, 'role': '', 'type': 'way'},
#   {'ref': 4305060164, 'role': '', 'type': 'way'},
#   {'ref': 4305060165, 'role': '', 'type': 'way'},
#   {'ref': 4305060166, 'role': '', 'type': 'way'},
#   {'ref': 4305060167, 'role': '', 'type': 'way'},
#   {'ref': 4305060168, 'role': '', 'type': 'way'},
#   {'ref': 4305060169, 'role': '', 'type': 'way'},
#   {'ref': 4305060170, 'role': '', 'type': 'way'},
#   {'ref': 4305060171, 'role': '', 'type': 'way'},
#   {'ref': 4305060172, 'role': '', 'type': 'way'},
#   {'ref': 4305060173, 'role': '', 'type': 'way'},
#   {'ref': 4305060174, 'role': '', 'type': 'way'},
#   {'ref': 4305060175, 'role': '', 'type': 'way'},
#   {'ref': 4305060176, 'role': '', 'type': 'way'},
#   {'ref': 4305060177, 'role': '', 'type': 'way'},
#   {'ref': 4305060178, 'role': '', 'type': 'way'},
#   {'ref': 4305060179, 'role': '', 'type': 'way'},
#   {'ref': 4305060180, 'role': '', 'type': 'way'},
#   {'ref': 4305060181, 'role': '', 'type': 'way'},
#   {'ref': 4305060182, 'role': '', 'type': 'way'},
#   {'ref': 4305060183, 'role': '', 'type': 'way'},
#   {'ref': 4305060184, 'role': '', 'type': 'way'},
#   {'ref': 4305060185, 'role': '', 'type': 'way'},
#   {'ref': 4305060186, 'role': '', 'type': 'way'},
#   {'ref': 4305060187, 'role': '', 'type': 'way'},
#   {'ref': 4305060188, 'role': '', 'type': 'way'},
#   {'ref': 4305060189, 'role': '', 'type': 'way'},
#   {'ref': 4305060190, 'role': '', 'type': 'way'},
#   {'ref': 4305060191, 'role': '', 'type': 'way'},
#   {'ref': 4305060192, 'role': '', 'type': 'way'},
#   {'ref': 4305060193, 'role': '', 'type': 'way'},
#   {'ref': 4305060194, 'role': '', 'type': 'way'},
#   {'ref': 4305060195, 'role': '', 'type': 'way'},
#   {'ref': 4305060196, 'role': '', 'type': 'way'},
#   {'ref': 4305060197, 'role': '', 'type': 'way'},
#   {'ref': 4305060198, 'role': '', 'type': 'way'},
#   {'ref': 4305060199, 'role': '', 'type': 'way'},
#   {'ref': 4305060200, 'role': '', 'type': 'way'},
#   {'ref': 4305060201, 'role': '', 'type': 'way'},
#   {'ref': 4305060202, 'role': '', 'type': 'way'},
#   {'ref': 4305060203, 'role': '', 'type': 'way'},
#   {'ref': 4305060204, 'role': '', 'type': 'way'},
#   {'ref': 4305060205, 'role': '', 'type': 'way'},
#   {'ref': 4305060206, 'role': '', 'type': 'way'},
#   {'ref': 4305060207, 'role': '', 'type': 'way'},
#   {'ref': 4305060208, 'role': '', 'type': 'way'},
#   {'ref': 4305060209, 'role': '', 'type': 'way'},
#   {'ref': 4305060210, 'role': '', 'type': 'way'},
#   {'ref': 4305060211, 'role': '', 'type': 'way'},
#   {'ref': 4305060212, 'role': '', 'type': 'way'},
#   {'ref': 4305060213, 'role': '', 'type': 'way'},
#   {'ref': 4305060214, 'role': '', 'type': 'way'},
#   {'ref': 4305060215, 'role': '', 'type': 'way'},
#   {'ref': 4305060216, 'role': '', 'type': 'way'},
#   {'ref': 4305060217, 'role': '', 'type': 'way'},
#   {'ref': 4305060218, 'role': '', 'type': 'way'},
#   {'ref': 4305060219, 'role': '', 'type': 'way'},
#   {'ref': 4305060220, 'role': '', 'type': 'way'},
#   {'ref': 4305060221, 'role': '', 'type': 'way'},
#   {'ref': 4305060222, 'role': '', 'type': 'way'},
#   {'ref': 4305060223, 'role': '', 'type': 'way'},
#   {'ref': 4305060224, 'role': '', 'type': 'way'},
#   {'ref': 4305060225, 'role': '', 'type': 'way'},
#   {'ref': 4305060226, 'role': '', 'type': 'way'},
#   {'ref': 4305060227, 'role': '', 'type': 'way'},
#   {'ref': 4305060228, 'role': '', 'type': 'way'},
#   {'ref': 4305060229, 'role': '', 'type': 'way'},
#   {'ref': 4305060230, 'role': '', 'type': 'way'},
#   {'ref': 4305060231, 'role': '', 'type': 'way'},
#   {'ref': 4305060232, 'role': '', 'type': 'way'},
#   {'ref': 4305060233, 'role': '', 'type': 'way'},
#   {'ref': 4305060234, 'role': '', 'type': 'way'},
#   {'ref': 4305060235, 'role': '', 'type': 'way'},
#   {'ref': 4305060236, 'role': '', 'type': 'way'},
#   {'ref': 4305060237, 'role': '', 'type': 'way'},
#   {'ref': 4305060238, 'role': '', 'type': 'way'},
#   {'ref': 4305060239, 'role': '', 'type': 'way'},
#   {'ref': 4305060240, 'role': '', 'type': 'way'},
#   {'ref': 4305060241, 'role': '', 'type': 'way'},
#   {'ref': 4305060242, 'role': '', 'type': 'way'},
#   {'ref': 4305060243, 'role': '', 'type': 'way'},
#   {'ref': 4305060244, 'role': '', 'type': 'way'},
#   {'ref': 4305060245, 'role': '', 'type': 'way'},
#   {'ref': 4305060246, 'role': '', 'type': 'way'},
#   {'ref': 4305060247, 'role': '', 'type': 'way'},
#   {'ref': 4305060248, 'role': '', 'type': 'way'},
#   {'ref': 4305060249, 'role': '', 'type': 'way'},
#   {'ref': 4305060250, 'role': '', 'type': 'way'},
#   {'ref': 4305060251, 'role': '', 'type': 'way'},
#   {'ref': 4305060252, 'role': '', 'type': 'way'},
#   {'ref': 4305060253, 'role': '', 'type': 'way'},
#   {'ref': 4305060254, 'role': '', 'type': 'way'},
#   {'ref': 4305060255, 'role': '', 'type': 'way'},
#   {'ref': 4305060256, 'role': '', 'type': 'way'},
#   {'ref': 4305060257, 'role': '', 'type': 'way'},
#   {'ref': 4305060258, 'role': '', 'type': 'way'},
#   {'ref': 4305060259, 'role': '', 'type': 'way'},
#   {'ref': 4305060260, 'role': '', 'type': 'way'},
#   {'ref': 4305060261, 'role': '', 'type': 'way'},
#   {'ref': 4305060262, 'role': '', 'type': 'way'},
#   {'ref': 4305060263, 'role': '', 'type': 'way'},
#   {'ref': 4305060264, 'role': '', 'type': 'way'},
#   {'ref': 4305060265, 'role': '', 'type': 'way'},
#   {'ref': 4305060266, 'role': '', 'type': 'way'},
#   {'ref': 4305060267, 'role': '', 'type': 'way'},
#   {'ref': 4305060268, 'role': '', 'type': 'way'},
#   {'ref': 4305060269, 'role': '', 'type': 'way'},
#   {'ref': 4305060270, 'role': '', 'type': 'way'},
#   {'ref': 4305060271, 'role': '', 'type': 'way'}],
#  'tag': {'name': 'Höltigbaum Route'},
#  'version': 1}
